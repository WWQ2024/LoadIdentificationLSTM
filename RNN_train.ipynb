# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
import joblib
import json
from matplotlib import rcParams

# 设置中文字体（这里以SimHei字体为例）
rcParams['font.sans-serif'] = ['SimHei']  # 指定中文字体
rcParams['axes.unicode_minus'] = False  # 解决负号显示问题

def load_mat_files_from_directory(directory_path):
    """
    从指定文件夹中加载所有.mat文件的数据
    
    参数:
        directory_path (str): 包含.mat文件的文件夹路径
    
    返回:
        tuple: (combined_load_data, combined_strain_data)
            - combined_load_data: 合并后的载荷数据
            - combined_strain_data: 合并后的应变数据
    """
    combined_load_data = []
    combined_strain_data = []
    
    # 获取文件夹中的所有.mat文件
    mat_files = [f for f in os.listdir(directory_path) if f.endswith('.mat')]
    mat_files.sort()  # 按文件名排序
    
    print(f"找到 {len(mat_files)} 个.mat文件")
    
    for mat_file in mat_files:
        file_path = os.path.join(directory_path, mat_file)
        print(f"正在加载: {mat_file}")
        
        try:
            # 加载.mat文件
            mat_data = scipy.io.loadmat(file_path)
            
            # 根据您的数据结构调整这些键名
            # 假设载荷数据的键名为'load'或'Load'，应变数据的键名为'strain'或'Strain'
            load_key = None
            strain_key = None
            
            # 查找可能的键名
            for key in mat_data.keys():
                if key.lower() in ['load', 'loads', 'force', 'forces']:
                    load_key = key
                elif key.lower() in ['strain', 'strains', 'displacement', 'displacements']:
                    strain_key = key
            
            # 如果没有找到标准键名，使用数据中的非私有键
            if load_key is None or strain_key is None:
                data_keys = [k for k in mat_data.keys() if not k.startswith('__')]
                if len(data_keys) >= 2:
                    load_key = data_keys[0]
                    strain_key = data_keys[1]
                    print(f"使用键名: load='{load_key}', strain='{strain_key}'")
            
            if load_key and strain_key:
                load_data = mat_data[load_key]
                strain_data = mat_data[strain_key]
                
                combined_load_data.append(load_data)
                combined_strain_data.append(strain_data)
                
                print(f"  载荷数据形状: {load_data.shape}")
                print(f"  应变数据形状: {strain_data.shape}")
            else:
                print(f"  警告: 无法在 {mat_file} 中找到载荷或应变数据")
                
        except Exception as e:
            print(f"  错误: 加载 {mat_file} 时出错: {e}")
    
    if combined_load_data and combined_strain_data:
        # 合并所有数据
        combined_load_data = np.concatenate(combined_load_data, axis=1)
        combined_strain_data = np.concatenate(combined_strain_data, axis=1)
        
        print(f"\n合并后的数据形状:")
        print(f"载荷数据: {combined_load_data.shape}")
        print(f"应变数据: {combined_strain_data.shape}")
        
        return combined_load_data, combined_strain_data
    else:
        raise ValueError("没有成功加载任何数据文件")

# 指定包含多个.mat文件的文件夹路径
mat_directory = r'/root/shared-nvme/SSH_remote/20250804LoadingIdentification/Data'  # 修改为您的文件夹路径

# 从文件夹中加载所有.mat文件的数据
combined_load_data, combined_strain_data = load_mat_files_from_directory(mat_directory)

# 转置数据，使时间为第一个维度
strain = combined_strain_data.T  # 形状: (总样本数, 10)
load = combined_load_data.T      # 形状: (总样本数, 1)

# 确保 load 是二维的，形状为 (样本数, 1)
if load.ndim > 2:
    load = load.squeeze()
if load.ndim == 1:
    load = load.reshape(-1, 1)
elif load.shape[1] != 1:
    load = load[:, 0:1]

# 标准化数据
strain_scaler = StandardScaler()
load_scaler = StandardScaler()

strain = strain_scaler.fit_transform(strain)  # 形状: (总样本数, 10)
load = load_scaler.fit_transform(load)        # 形状: (总样本数, 1)

# 保存scalers，以便后续使用
joblib.dump(strain_scaler, 'strain_scaler.save')
joblib.dump(load_scaler, 'load_scaler.save')
current_path = os.getcwd()
print("当前 notebook 文件所在目录为:", current_path)

# 2. 数据切片
def create_time_windows(data, window_size=2048, overlap=0.5):
    """
    将数据切分成时间窗口。
    
    参数:
        data (numpy.ndarray): 输入数据，形状为 (样本数, 特征数)。
        window_size (int): 每个窗口的大小。
        overlap (float): 窗口之间的重叠比例。
        
    返回:
        windows (numpy.ndarray): 切分后的数据，形状为 (窗口数, window_size, 特征数)。
    """
    step = int(window_size * (1 - overlap))
    num_samples = data.shape[0]
    num_features = data.shape[1]
    
    num_windows = (num_samples - window_size) // step + 1
    windows = np.zeros((num_windows, window_size, num_features))
    
    for i in range(num_windows):
        start = i * step
        end = start + window_size
        windows[i] = data[start:end]
    
    return windows

# 定义窗口大小和重叠比例
window_size = 2048
overlap = 0.5

# 切片应变数据和载荷数据
strain_windows = create_time_windows(strain, window_size=window_size, overlap=overlap)  # 形状: (num_windows, 2048, 10)
load_windows = create_time_windows(load, window_size=window_size, overlap=overlap)        # 形状: (num_windows, 2048, 1)

print(f'应变窗口形状: {strain_windows.shape}')  # 例如: (num_windows, 2048, 10)
print(f'载荷窗口形状: {load_windows.shape}')    # 例如: (num_windows, 2048, 1)

# 3. 创建数据集
class StrainLoadTimeDomainDataset(Dataset):
    def __init__(self, strain_windows, load_windows):
        self.strain = torch.tensor(strain_windows, dtype=torch.float32)  # 形状: (num_windows, 2048, 10)
        self.load = torch.tensor(load_windows, dtype=torch.float32)      # 形状: (num_windows, 2048, 1)

    def __len__(self):
        return self.strain.shape[0]

    def __getitem__(self, idx):
        # 返回应变序列和载荷序列
        strain_sample = self.strain[idx]  # 形状: (2048, 10)
        load_sample = self.load[idx]      # 形状: (2048, 1)
        return strain_sample, load_sample

# 拆分训练集和验证集
X_train, X_val, y_train, y_val = train_test_split(
    strain_windows, load_windows, test_size=0.2, random_state=42
)

# 创建数据集对象
train_dataset = StrainLoadTimeDomainDataset(X_train, y_train)
val_dataset = StrainLoadTimeDomainDataset(X_val, y_val)

# 创建数据加载器
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# 4. 定义RNN模型
class RNNModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size, 
                 rnn_type='RNN', dropout=0.2, bidirectional=False):
        """
        初始化RNN模型
        
        参数:
        - input_size: 输入特征的数量（应变数据的特征数，例如10）
        - hidden_size: RNN隐藏层大小
        - num_layers: RNN层数
        - output_size: 输出特征的数量（载荷数据的特征数，例如1）
        - rnn_type: RNN类型，可选 'RNN', 'LSTM', 'GRU'
        - dropout: dropout概率
        - bidirectional: 是否使用双向RNN
        """
        super(RNNModel, self).__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.output_size = output_size
        self.rnn_type = rnn_type
        self.bidirectional = bidirectional
        
        # 选择RNN类型
        if rnn_type == 'RNN':
            self.rnn = nn.RNN(input_size, hidden_size, num_layers, 
                            batch_first=True, dropout=dropout if num_layers > 1 else 0,
                            bidirectional=bidirectional)
        elif rnn_type == 'LSTM':
            self.rnn = nn.LSTM(input_size, hidden_size, num_layers, 
                             batch_first=True, dropout=dropout if num_layers > 1 else 0,
                             bidirectional=bidirectional)
        elif rnn_type == 'GRU':
            self.rnn = nn.GRU(input_size, hidden_size, num_layers, 
                            batch_first=True, dropout=dropout if num_layers > 1 else 0,
                            bidirectional=bidirectional)
        else:
            raise ValueError(f"不支持的RNN类型: {rnn_type}")
        
        # 计算线性层输入维度
        linear_input_size = hidden_size * 2 if bidirectional else hidden_size
        
        # 输出线性层
        self.fc = nn.Linear(linear_input_size, output_size)
        
        # Dropout层
        self.dropout = nn.Dropout(dropout)
        
        # 初始化权重
        self.init_weights()
    
    def init_weights(self):
        """初始化模型权重"""
        for name, param in self.rnn.named_parameters():
            if 'weight_ih' in name:
                nn.init.xavier_uniform_(param.data)
            elif 'weight_hh' in name:
                nn.init.orthogonal_(param.data)
            elif 'bias' in name:
                param.data.fill_(0)
        
        # 初始化线性层
        nn.init.xavier_uniform_(self.fc.weight)
        nn.init.constant_(self.fc.bias, 0)
    
    def forward(self, x):
        """
        前向传播
        
        参数:
        - x: 输入张量，形状为 (batch_size, seq_len, input_size)
        
        返回:
        - output: 输出张量，形状为 (batch_size, seq_len, output_size)
        """
        batch_size, seq_len, _ = x.shape
        
        # 初始化隐藏状态
        num_directions = 2 if self.bidirectional else 1
        
        if self.rnn_type == 'LSTM':
            h0 = torch.zeros(self.num_layers * num_directions, batch_size, self.hidden_size).to(x.device)
            c0 = torch.zeros(self.num_layers * num_directions, batch_size, self.hidden_size).to(x.device)
            rnn_output, _ = self.rnn(x, (h0, c0))
        else:
            h0 = torch.zeros(self.num_layers * num_directions, batch_size, self.hidden_size).to(x.device)
            rnn_output, _ = self.rnn(x, h0)
        
        # 应用dropout
        rnn_output = self.dropout(rnn_output)
        
        # 通过线性层
        output = self.fc(rnn_output)  # 形状: (batch_size, seq_len, output_size)
        
        return output
    
    def count_parameters(self):
        """计算模型参数数量"""
        return sum(p.numel() for p in self.parameters() if p.requires_grad)

class MultiRNNModel(nn.Module):
    def __init__(self, input_size, hidden_sizes, output_size, 
                 rnn_types=None, dropout=0.2, bidirectional=False):
        """
        多层混合RNN模型，可以组合不同类型的RNN
        
        参数:
        - input_size: 输入特征数量
        - hidden_sizes: 每层隐藏层大小的列表
        - output_size: 输出特征数量
        - rnn_types: 每层RNN类型的列表，如果为None则全部使用'RNN'
        - dropout: dropout概率
        - bidirectional: 是否使用双向RNN
        """
        super(MultiRNNModel, self).__init__()
        
        self.num_layers = len(hidden_sizes)
        self.hidden_sizes = hidden_sizes
        self.bidirectional = bidirectional
        
        if rnn_types is None:
            rnn_types = ['RNN'] * self.num_layers
        
        self.rnn_layers = nn.ModuleList()
        self.dropout_layers = nn.ModuleList()
        
        # 构建多层RNN
        for i in range(self.num_layers):
            input_dim = input_size if i == 0 else (hidden_sizes[i-1] * (2 if bidirectional else 1))
            
            if rnn_types[i] == 'RNN':
                rnn_layer = nn.RNN(input_dim, hidden_sizes[i], 1, 
                                 batch_first=True, bidirectional=bidirectional)
            elif rnn_types[i] == 'LSTM':
                rnn_layer = nn.LSTM(input_dim, hidden_sizes[i], 1, 
                                  batch_first=True, bidirectional=bidirectional)
            elif rnn_types[i] == 'GRU':
                rnn_layer = nn.GRU(input_dim, hidden_sizes[i], 1, 
                                 batch_first=True, bidirectional=bidirectional)
            else:
                raise ValueError(f"不支持的RNN类型: {rnn_types[i]}")
            
            self.rnn_layers.append(rnn_layer)
            self.dropout_layers.append(nn.Dropout(dropout))
        
        # 输出层
        final_hidden_size = hidden_sizes[-1] * (2 if bidirectional else 1)
        self.fc = nn.Linear(final_hidden_size, output_size)
        
        # 保存配置
        self.rnn_types = rnn_types
        
        # 初始化权重
        self.init_weights()
    
    def init_weights(self):
        """初始化模型权重"""
        for rnn_layer in self.rnn_layers:
            for name, param in rnn_layer.named_parameters():
                if 'weight_ih' in name:
                    nn.init.xavier_uniform_(param.data)
                elif 'weight_hh' in name:
                    nn.init.orthogonal_(param.data)
                elif 'bias' in name:
                    param.data.fill_(0)
        
        # 初始化线性层
        nn.init.xavier_uniform_(self.fc.weight)
        nn.init.constant_(self.fc.bias, 0)
    
    def forward(self, x):
        """
        前向传播
        
        参数:
        - x: 输入张量，形状为 (batch_size, seq_len, input_size)
        
        返回:
        - output: 输出张量，形状为 (batch_size, seq_len, output_size)
        """
        batch_size = x.size(0)
        num_directions = 2 if self.bidirectional else 1
        
        # 逐层处理
        for i, (rnn_layer, dropout_layer) in enumerate(zip(self.rnn_layers, self.dropout_layers)):
            if self.rnn_types[i] == 'LSTM':
                h0 = torch.zeros(num_directions, batch_size, self.hidden_sizes[i]).to(x.device)
                c0 = torch.zeros(num_directions, batch_size, self.hidden_sizes[i]).to(x.device)
                x, _ = rnn_layer(x, (h0, c0))
            else:
                h0 = torch.zeros(num_directions, batch_size, self.hidden_sizes[i]).to(x.device)
                x, _ = rnn_layer(x, h0)
            
            x = dropout_layer(x)
        
        # 输出层
        output = self.fc(x)
        
        return output
    
    def count_parameters(self):
        """计算模型参数数量"""
        return sum(p.numel() for p in self.parameters() if p.requires_grad)

# 初始化模型参数
input_size = 10        # 应变数据的特征数量
output_size = 1        # 载荷数据的特征数量

# 选择模型类型和参数
model_type = "MultiRNN"  # 可选: "RNN", "MultiRNN"

if model_type == "RNN":
    # 单一RNN模型
    hidden_size = 1024     # RNN隐藏层大小
    num_layers = 6        # RNN层数
    rnn_type = 'RNN'      # 可选: 'RNN', 'LSTM', 'GRU'
    bidirectional = False  # 是否双向
    dropout = 0.2
    
    model = RNNModel(
        input_size=input_size,
        hidden_size=hidden_size,
        num_layers=num_layers,
        output_size=output_size,
        rnn_type=rnn_type,
        dropout=dropout,
        bidirectional=bidirectional
    )
    
    model_config = {
        'model_type': 'RNN',
        'input_size': input_size,
        'hidden_size': hidden_size,
        'num_layers': num_layers,
        'output_size': output_size,
        'rnn_type': rnn_type,
        'dropout': dropout,
        'bidirectional': bidirectional
    }

else:  # MultiRNN
    # 多层混合RNN模型，参数调整以匹配之前模型的参数量
    hidden_sizes = [256, 512, 512, 256, 128, 64]  # 每层隐藏层大小
    rnn_types = ['RNN', 'GRU', 'LSTM', 'GRU', 'RNN', 'RNN']  # 混合不同类型的RNN
    bidirectional = False
    dropout = 0.2
    
    model = MultiRNNModel(
        input_size=input_size,
        hidden_sizes=hidden_sizes,
        output_size=output_size,
        rnn_types=rnn_types,
        dropout=dropout,
        bidirectional=bidirectional
    )
    
    model_config = {
        'model_type': 'MultiRNN',
        'input_size': input_size,
        'hidden_sizes': hidden_sizes,
        'output_size': output_size,
        'rnn_types': rnn_types,
        'dropout': dropout,
        'bidirectional': bidirectional
    }

# 打印模型参数数量
total_params = model.count_parameters()
print(f"RNN模型总参数数量: {total_params:,}")
print(f"模型结构:\n{model}")

# 移动模型到GPU（如果可用）
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
print(f"使用设备: {device}")

# 定义损失函数和优化器
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# 学习率调度器
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=20, verbose=True)

# 5. 训练与验证流程
num_epochs = 300  # 根据需要调整
best_val_loss = float('inf')
patience = 100  # 早停耐心值
counter = 0

# 记录训练历史
train_losses = []
val_losses = []

print("开始训练RNN模型...")

for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    
    for batch_idx, (strain, load) in enumerate(train_loader):
        strain = strain.to(device)  # 形状: (batch_size, 2048, 10)
        load = load.to(device)      # 形状: (batch_size, 2048, 1)
        
        # 前向传播
        outputs = model(strain)     # 形状: (batch_size, 2048, 1)
        loss = criterion(outputs, load)
        
        # 反向传播和优化
        optimizer.zero_grad()
        loss.backward()
        
        # 梯度裁剪（防止梯度爆炸）
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        
        optimizer.step()
        
        train_loss += loss.item() * strain.size(0)
    
    avg_train_loss = train_loss / len(train_loader.dataset)
    train_losses.append(avg_train_loss)
    
    # 验证
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for strain, load in val_loader:
            strain = strain.to(device)
            load = load.to(device)
            
            outputs = model(strain)
            loss = criterion(outputs, load)
            val_loss += loss.item() * strain.size(0)
    
    avg_val_loss = val_loss / len(val_loader.dataset)
    val_losses.append(avg_val_loss)
    
    # 学习率调度
    scheduler.step(avg_val_loss)
    
    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {avg_train_loss:.6f}, Val Loss: {avg_val_loss:.6f}')
    
    # 早停检查
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        counter = 0
        # 保存最好的模型
        torch.save(model.state_dict(), 'best_rnn_model.pth')
    else:
        counter += 1
        if counter >= patience:
            print("早停触发！")
            break

print("训练完成！")

# 6. 载入最好的模型
model.load_state_dict(torch.load('best_rnn_model.pth'))

# 7. 定义评估指标
def calculate_metrics(y_true, y_pred):
    """
    计算预测指标：RMSE, MAE, RRMSE, TRAC
    
    参数:
        y_true: 真实值
        y_pred: 预测值
    
    返回:
        dict: 包含各项指标的字典
    """
    # 确保输入为numpy数组
    if torch.is_tensor(y_true):
        y_true = y_true.cpu().numpy()
    if torch.is_tensor(y_pred):
        y_pred = y_pred.cpu().numpy()
    
    # 展平数组以便计算
    y_true_flat = y_true.flatten()
    y_pred_flat = y_pred.flatten()
    
    # RMSE (Root Mean Square Error)
    rmse = np.sqrt(np.mean((y_true_flat - y_pred_flat) ** 2))
    
    # MAE (Mean Absolute Error)
    mae = np.mean(np.abs(y_true_flat - y_pred_flat))
    
    # RRMSE (Relative Root Mean Square Error)
    # RRMSE = RMSE / mean(|y_true|) * 100%
    mean_true = np.mean(np.abs(y_true_flat))
    rrmse = (rmse / mean_true) * 100 if mean_true != 0 else float('inf')
    
    # TRAC (Tracking Coefficient) - 通常指相关系数的平方
    correlation_matrix = np.corrcoef(y_true_flat, y_pred_flat)
    correlation = correlation_matrix[0, 1]
    trac = correlation ** 2  # R^2
    
    return {
        'RMSE': rmse,
        'MAE': mae,
        'RRMSE': rrmse,
        'TRAC': trac,
        'R': correlation  # 额外返回相关系数
    }

# 8. 评估模型
model.eval()
all_predictions = []
all_targets = []

print("正在评估RNN模型...")
with torch.no_grad():
    for batch_idx, (strain, load) in enumerate(val_loader):
        strain = strain.to(device)
        load = load.to(device)
        
        outputs = model(strain)
        
        # 反标准化预测结果和真实值
        outputs_cpu = outputs.cpu()
        load_cpu = load.cpu()
        
        # 将数据reshape为(batch_size * seq_length, 1)以便反标准化
        outputs_reshaped = outputs_cpu.view(-1, 1)
        load_reshaped = load_cpu.view(-1, 1)
        
        # 反标准化
        outputs_denorm = load_scaler.inverse_transform(outputs_reshaped)
        load_denorm = load_scaler.inverse_transform(load_reshaped)
        
        # 重新reshape回原来的形状
        outputs_denorm = outputs_denorm.reshape(outputs_cpu.shape)
        load_denorm = load_denorm.reshape(load_cpu.shape)
        
        all_predictions.append(outputs_denorm)
        all_targets.append(load_denorm)
        
        if batch_idx % 10 == 0:
            print(f'处理批次 {batch_idx + 1}/{len(val_loader)}')

# 合并所有预测和目标
all_predictions = np.concatenate(all_predictions, axis=0)
all_targets = np.concatenate(all_targets, axis=0)

print(f'预测数据形状: {all_predictions.shape}')
print(f'目标数据形状: {all_targets.shape}')

# 计算评估指标
metrics = calculate_metrics(all_targets, all_predictions)

# 打印结果
print("\n=== RNN模型评估结果 ===")
print(f"模型参数数量: {total_params:,}")
print(f"模型类型: {model_config['model_type']}")
if model_config['model_type'] == 'MultiRNN':
    print(f"RNN层类型: {model_config['rnn_types']}")
    print(f"隐藏层大小: {model_config['hidden_sizes']}")
else:
    print(f"RNN类型: {model_config['rnn_type']}")
    print(f"隐藏层大小: {model_config['hidden_size']}")
    print(f"层数: {model_config['num_layers']}")
print(f"RMSE:  {metrics['RMSE']:.6f}")
print(f"MAE:   {metrics['MAE']:.6f}")
print(f"RRMSE: {metrics['RRMSE']:.4f}%")
print(f"TRAC:  {metrics['TRAC']:.6f}")
print(f"相关系数R: {metrics['R']:.6f}")

# 额外计算一些统计信息
print(f"\n=== 额外统计信息 ===")
print(f"真实值均值: {np.mean(all_targets):.6f}")
print(f"预测值均值: {np.mean(all_predictions):.6f}")
print(f"真实值标准差: {np.std(all_targets):.6f}")
print(f"预测值标准差: {np.std(all_predictions):.6f}")

# 保存评估结果
metrics_save = {
    'model_type': model_config['model_type'],
    'total_params': int(total_params),
    'RMSE': float(metrics['RMSE']),
    'MAE': float(metrics['MAE']),
    'RRMSE': float(metrics['RRMSE']),
    'TRAC': float(metrics['TRAC']),
    'R': float(metrics['R']),
    'mean_true': float(np.mean(all_targets)),
    'mean_pred': float(np.mean(all_predictions)),
    'std_true': float(np.std(all_targets)),
    'std_pred': float(np.std(all_predictions)),
    'best_val_loss': float(best_val_loss)
}

# 保存指标到文件
with open('rnn_evaluation_metrics.json', 'w') as f:
    json.dump(metrics_save, f, indent=4)

print(f"\n评估指标已保存到 rnn_evaluation_metrics.json")

# 保存完整的模型和配置
torch.save({
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'model_config': model_config,
    'metrics': metrics_save,
    'total_params': total_params,
    'train_losses': train_losses,
    'val_losses': val_losses
}, 'best_rnn_model_dwell.pth')

print(f'保存最佳RNN模型，验证损失: {best_val_loss:.6f}')

# 保存训练损失历史
loss_history = {
    'train_losses': train_losses,
    'val_losses': val_losses,
    'epochs': list(range(1, len(train_losses) + 1))
}

with open('rnn_loss_history.json', 'w') as f:
    json.dump(loss_history, f, indent=4)

print("训练损失历史已保存到 rnn_loss_history.json")

# 绘制训练和验证损失曲线
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Training Loss', linewidth=2)
plt.plot(range(1, len(val_losses) + 1), val_losses, label='Validation Loss', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('RNN Model Training and Validation Loss')
plt.legend()
plt.grid(True, alpha=0.3)
plt.yscale('log')  # 使用对数尺度
plt.tight_layout()
plt.savefig('rnn_training_loss.png', dpi=300, bbox_inches='tight')
plt.show()

# 9. RNN模型分析和可视化
def analyze_rnn_gradients(model, sample_input):
    """分析RNN模型的梯度流"""
    model.eval()
    sample_input.requires_grad_(True)
    
    output = model(sample_input)
    loss = output.sum()
    loss.backward()
    
    gradients = []
    for name, param in model.named_parameters():
        if param.grad is not None:
            gradients.append(param.grad.norm().item())
    
    return gradients

# 可视化模型架构
plt.figure(figsize=(15, 10))

if model_config['model_type'] == 'MultiRNN':
    # 子图1: 各层隐藏单元数
    plt.subplot(2, 3, 1)
    layers = list(range(len(model_config['hidden_sizes'])))
    plt.bar(layers, model_config['hidden_sizes'], alpha=0.7, color='skyblue')
    plt.xlabel('Layer')
    plt.ylabel('Hidden Units')
    plt.title('Hidden Units per Layer')
    plt.grid(True, alpha=0.3)
    
    # 子图2: RNN类型分布
    plt.subplot(2, 3, 2)
    rnn_type_counts = {}
    for rnn_type in model_config['rnn_types']:
        rnn_type_counts[rnn_type] = rnn_type_counts.get(rnn_type, 0) + 1
    
    plt.pie(rnn_type_counts.values(), labels=rnn_type_counts.keys(), autopct='%1.1f%%', startangle=90)
    plt.title('RNN Type Distribution')

else:
    # 单一RNN模型
    plt.subplot(2, 3, 1)
    plt.bar([model_config['rnn_type']], [model_config['hidden_size']], alpha=0.7, color='skyblue')
    plt.ylabel('Hidden Units')
    plt.title('RNN Configuration')
    plt.grid(True, alpha=0.3)

# 子图3: 参数分布
plt.subplot(2, 3, 3)
param_counts = []
param_names = []

for name, param in model.named_parameters():
    if param.requires_grad:
        # 简化参数名称
        simplified_name = name.split('.')[0] if '.' in name else name
        if simplified_name not in param_names:
            param_names.append(simplified_name)
            param_counts.append(param.numel())
        else:
            idx = param_names.index(simplified_name)
            param_counts[idx] += param.numel()

plt.pie(param_counts, labels=param_names, autopct='%1.1f%%', startangle=90)
plt.title('Parameter Distribution')

# 子图4: 训练损失曲线
plt.subplot(2, 3, 4)
plt.plot(train_losses, label='Training Loss', alpha=0.8)
plt.plot(val_losses, label='Validation Loss', alpha=0.8)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training History')
plt.legend()
plt.yscale('log')
plt.grid(True, alpha=0.3)

# 子图5: 预测vs真实值散点图
plt.subplot(2, 3, 5)
# 随机采样一些点进行可视化
sample_indices = np.random.choice(len(all_targets.flatten()), min(5000, len(all_targets.flatten())), replace=False)
true_sample = all_targets.flatten()[sample_indices]
pred_sample = all_predictions.flatten()[sample_indices]

plt.scatter(true_sample, pred_sample, alpha=0.5, s=1)
plt.plot([true_sample.min(), true_sample.max()], [true_sample.min(), true_sample.max()], 'r--', lw=2)
plt.xlabel('True Values')
plt.ylabel('Predicted Values')
plt.title('Prediction vs True')
plt.grid(True, alpha=0.3)

# 子图6: 残差分析
plt.subplot(2, 3, 6)
residuals = pred_sample - true_sample
plt.hist(residuals, bins=50, alpha=0.7, density=True)
plt.xlabel('Residuals')
plt.ylabel('Density')
plt.title('Residual Distribution')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('rnn_model_analysis.png', dpi=300, bbox_inches='tight')
plt.show()

# 计算并显示模型复杂度信息
def calculate_model_complexity():
    """计算模型复杂度信息"""
    if model_config['model_type'] == 'MultiRNN':
        total_hidden_units = sum(model_config['hidden_sizes'])
        num_layers = len(model_config['hidden_sizes'])
        avg_hidden_size = total_hidden_units / num_layers
    else:
        total_hidden_units = model_config['hidden_size'] * model_config['num_layers']
        num_layers = model_config['num_layers']
        avg_hidden_size = model_config['hidden_size']
    
    return {
        'total_hidden_units': total_hidden_units,
        'num_layers': num_layers,
        'avg_hidden_size': avg_hidden_size,
        'total_params': total_params
    }

complexity_info = calculate_model_complexity()

print(f"\n=== RNN模型复杂度分析 ===")
print(f"总隐藏单元数: {complexity_info['total_hidden_units']:,}")
print(f"网络层数: {complexity_info['num_layers']}")
print(f"平均隐藏层大小: {complexity_info['avg_hidden_size']:.1f}")
print(f"总参数量: {complexity_info['total_params']:,}")
print(f"序列长度: {window_size}")

# 清理GPU缓存
torch.cuda.empty_cache()

print("\n所有任务完成！")
print("生成的文件:")
print("- best_rnn_model.pth: 最佳模型权重")
print("- best_rnn_model_dwell.pth: 完整模型信息")
print("- rnn_evaluation_metrics.json: 评估指标")
print("- rnn_loss_history.json: 训练历史")
print("- rnn_training_loss.png: 损失曲线图")
print("- rnn_model_analysis.png: 模型分析图")
print("- strain_scaler.save: 应变数据标准化器")
print("- load_scaler.save: 载荷数据标准化器")

print(f"\nRNN模型特点:")
print(f"- 总参数量: {total_params:,}")
print(f"- 模型类型: {model_config['model_type']}")
if model_config['model_type'] == 'MultiRNN':
    print(f"- 混合RNN架构: {set(model_config['rnn_types'])}")
    print(f"- 层数: {len(model_config['hidden_sizes'])}")
else:
    print(f"- RNN类型: {model_config['rnn_type']}")
    print(f"- 层数: {model_config['num_layers']}")
print(f"- 序列建模能力强")
print(f"- 适合处理时序依赖关系")
# Out:
# 找到 1 个.mat文件
# 正在加载: Load_Strain_random_normal.mat
# 使用键名: load='load_data', strain='strain_data'
#   载荷数据形状: (1, 1309696)
#   应变数据形状: (10, 1309696)
#
# 合并后的数据形状:
# 载荷数据: (1, 1309696)
# 应变数据: (10, 1309696)
# 当前 notebook 文件所在目录为: /root/shared-nvme/SSH_remote/20250804LoadingIdentification
# 应变窗口形状: (1278, 2048, 10)
# 载荷窗口形状: (1278, 2048, 1)
# RNN模型总参数数量: 4,005,825
# 模型结构:
# MultiRNNModel(
#   (rnn_layers): ModuleList(
#     (0): RNN(10, 256, batch_first=True)
#     (1): GRU(256, 512, batch_first=True)
#     (2): LSTM(512, 512, batch_first=True)
#     (3): GRU(512, 256, batch_first=True)
#     (4): RNN(256, 128, batch_first=True)
#     (5): RNN(128, 64, batch_first=True)
#   )
#   (dropout_layers): ModuleList(
#     (0-5): 6 x Dropout(p=0.2, inplace=False)
#   )
#   (fc): Linear(in_features=64, out_features=1, bias=True)
# )
# 使用设备: cuda
# 开始训练RNN模型...
# Epoch [1/300], Train Loss: 1.306462, Val Loss: 0.971584
# Epoch [2/300], Train Loss: 0.921510, Val Loss: 0.772197
# Epoch [3/300], Train Loss: 0.745477, Val Loss: 0.659886
# Epoch [4/300], Train Loss: 0.662399, Val Loss: 0.628478
# Epoch [5/300], Train Loss: 0.583018, Val Loss: 0.529286
# Epoch [6/300], Train Loss: 0.538133, Val Loss: 0.489359
# Epoch [7/300], Train Loss: 0.507850, Val Loss: 0.463222
# Epoch [8/300], Train Loss: 0.483127, Val Loss: 0.438452
# Epoch [9/300], Train Loss: 0.456931, Val Loss: 0.441642
# Epoch [10/300], Train Loss: 0.437433, Val Loss: 0.407153
# Epoch [11/300], Train Loss: 0.423343, Val Loss: 0.389346
# Epoch [12/300], Train Loss: 0.402940, Val Loss: 0.370384
# Epoch [13/300], Train Loss: 0.392798, Val Loss: 0.355548
# Epoch [14/300], Train Loss: 0.383631, Val Loss: 0.364805
# Epoch [15/300], Train Loss: 0.370503, Val Loss: 0.346184
# Epoch [16/300], Train Loss: 0.366961, Val Loss: 0.328168
# Epoch [17/300], Train Loss: 0.349965, Val Loss: 0.340179
# Epoch [18/300], Train Loss: 0.340922, Val Loss: 0.326615
# Epoch [19/300], Train Loss: 0.326398, Val Loss: 0.306509
# Epoch [20/300], Train Loss: 0.319199, Val Loss: 0.302117
# Epoch [21/300], Train Loss: 0.312042, Val Loss: 0.297880
# Epoch [22/300], Train Loss: 0.298416, Val Loss: 0.285547
# Epoch [23/300], Train Loss: 0.293366, Val Loss: 0.280285
# Epoch [24/300], Train Loss: 0.288940, Val Loss: 0.275018
# Epoch [25/300], Train Loss: 0.278981, Val Loss: 0.279877
# Epoch [26/300], Train Loss: 0.273110, Val Loss: 0.273733
# Epoch [27/300], Train Loss: 0.268047, Val Loss: 0.263850
# Epoch [28/300], Train Loss: 0.258749, Val Loss: 0.251658
# Epoch [29/300], Train Loss: 0.251006, Val Loss: 0.244038
# Epoch [30/300], Train Loss: 0.246824, Val Loss: 0.255465
# Epoch [31/300], Train Loss: 0.240578, Val Loss: 0.239721
# Epoch [32/300], Train Loss: 0.233733, Val Loss: 0.231079
# Epoch [33/300], Train Loss: 0.227770, Val Loss: 0.235266
# Epoch [34/300], Train Loss: 0.227201, Val Loss: 0.234421
# Epoch [35/300], Train Loss: 0.225138, Val Loss: 0.245666
# Epoch [36/300], Train Loss: 0.220304, Val Loss: 0.215857
# Epoch [37/300], Train Loss: 0.213943, Val Loss: 0.233363
# Epoch [38/300], Train Loss: 0.213084, Val Loss: 0.208626
# Epoch [39/300], Train Loss: 0.203288, Val Loss: 0.215898
# Epoch [40/300], Train Loss: 0.199521, Val Loss: 0.210509
# Epoch [41/300], Train Loss: 0.198474, Val Loss: 0.200222
# Epoch [42/300], Train Loss: 0.190626, Val Loss: 0.198299
# Epoch [43/300], Train Loss: 0.192071, Val Loss: 0.197091
# Epoch [44/300], Train Loss: 0.186081, Val Loss: 0.192261
# Epoch [45/300], Train Loss: 0.181557, Val Loss: 0.197442
# Epoch [46/300], Train Loss: 0.178334, Val Loss: 0.191374
# Epoch [47/300], Train Loss: 0.176255, Val Loss: 0.185044
# Epoch [48/300], Train Loss: 0.173562, Val Loss: 0.181215
# Epoch [49/300], Train Loss: 0.167750, Val Loss: 0.183375
# Epoch [50/300], Train Loss: 0.166092, Val Loss: 0.182729
# Epoch [51/300], Train Loss: 0.166410, Val Loss: 0.175781
# Epoch [52/300], Train Loss: 0.160815, Val Loss: 0.175110
# Epoch [53/300], Train Loss: 0.167459, Val Loss: 0.174019
# Epoch [54/300], Train Loss: 0.156263, Val Loss: 0.180187
# Epoch [55/300], Train Loss: 0.154544, Val Loss: 0.177994
# Epoch [56/300], Train Loss: 0.157390, Val Loss: 0.203185
# Epoch [57/300], Train Loss: 0.156961, Val Loss: 0.175389
# Epoch [58/300], Train Loss: 0.149994, Val Loss: 0.176745
# Epoch [59/300], Train Loss: 0.146399, Val Loss: 0.163969
# Epoch [60/300], Train Loss: 0.142376, Val Loss: 0.162496
# Epoch [61/300], Train Loss: 0.145053, Val Loss: 0.165407
# Epoch [62/300], Train Loss: 0.140911, Val Loss: 0.158777
# Epoch [63/300], Train Loss: 0.140859, Val Loss: 0.169649
# Epoch [64/300], Train Loss: 0.142043, Val Loss: 0.168441
# Epoch [65/300], Train Loss: 0.137721, Val Loss: 0.158516
# Epoch [66/300], Train Loss: 0.136893, Val Loss: 0.153156
# Epoch [67/300], Train Loss: 0.134310, Val Loss: 0.155308
# Epoch [68/300], Train Loss: 0.133038, Val Loss: 0.151193
# Epoch [69/300], Train Loss: 0.134132, Val Loss: 0.163210
# Epoch [70/300], Train Loss: 0.129884, Val Loss: 0.160184
# Epoch [71/300], Train Loss: 0.128545, Val Loss: 0.152791
# Epoch [72/300], Train Loss: 0.126302, Val Loss: 0.153961
# Epoch [73/300], Train Loss: 0.122387, Val Loss: 0.143884
# Epoch [74/300], Train Loss: 0.122556, Val Loss: 0.147077
# Epoch [75/300], Train Loss: 0.121207, Val Loss: 0.150688
# Epoch [76/300], Train Loss: 0.123746, Val Loss: 0.147969
# Epoch [77/300], Train Loss: 0.124527, Val Loss: 0.146566
# Epoch [78/300], Train Loss: 0.120629, Val Loss: 0.155775
# Epoch [79/300], Train Loss: 0.119954, Val Loss: 0.144407
# Epoch [80/300], Train Loss: 0.118628, Val Loss: 0.148944
# Epoch [81/300], Train Loss: 0.118662, Val Loss: 0.138662
# Epoch [82/300], Train Loss: 0.111847, Val Loss: 0.139297
# Epoch [83/300], Train Loss: 0.115227, Val Loss: 0.139537
# Epoch [84/300], Train Loss: 0.111377, Val Loss: 0.138909
# Epoch [85/300], Train Loss: 0.116071, Val Loss: 0.142613
# Epoch [86/300], Train Loss: 0.112301, Val Loss: 0.147588
# Epoch [87/300], Train Loss: 0.112863, Val Loss: 0.138746
# Epoch [88/300], Train Loss: 0.108707, Val Loss: 0.138314
# Epoch [89/300], Train Loss: 0.110390, Val Loss: 0.149104
# Epoch [90/300], Train Loss: 0.112461, Val Loss: 0.144574
# Epoch [91/300], Train Loss: 0.110921, Val Loss: 0.133273
# Epoch [92/300], Train Loss: 0.103349, Val Loss: 0.132606
# Epoch [93/300], Train Loss: 0.103302, Val Loss: 0.132148
# Epoch [94/300], Train Loss: 0.106364, Val Loss: 0.136306
# Epoch [95/300], Train Loss: 0.107124, Val Loss: 0.137072
# Epoch [96/300], Train Loss: 0.104853, Val Loss: 0.138925
# Epoch [97/300], Train Loss: 0.103755, Val Loss: 0.128139
# Epoch [98/300], Train Loss: 0.097221, Val Loss: 0.129364
# Epoch [99/300], Train Loss: 0.100861, Val Loss: 0.127722
# Epoch [100/300], Train Loss: 0.099520, Val Loss: 0.129739
# Epoch [101/300], Train Loss: 0.098421, Val Loss: 0.134993
# Epoch [102/300], Train Loss: 0.103305, Val Loss: 0.127499
# Epoch [103/300], Train Loss: 0.104406, Val Loss: 0.126767
# Epoch [104/300], Train Loss: 0.095580, Val Loss: 0.128531
# Epoch [105/300], Train Loss: 0.094182, Val Loss: 0.126123
# Epoch [106/300], Train Loss: 0.095279, Val Loss: 0.127948
# Epoch [107/300], Train Loss: 0.095553, Val Loss: 0.127610
# Epoch [108/300], Train Loss: 0.097081, Val Loss: 0.127751
# Epoch [109/300], Train Loss: 0.098541, Val Loss: 0.128441
# Epoch [110/300], Train Loss: 0.097803, Val Loss: 0.131754
# Epoch [111/300], Train Loss: 0.099104, Val Loss: 0.134769
# Epoch [112/300], Train Loss: 0.094858, Val Loss: 0.124849
# Epoch [113/300], Train Loss: 0.093440, Val Loss: 0.127715
# Epoch [114/300], Train Loss: 0.095290, Val Loss: 0.123473
# Epoch [115/300], Train Loss: 0.088638, Val Loss: 0.124247
# Epoch [116/300], Train Loss: 0.087351, Val Loss: 0.118489
# Epoch [117/300], Train Loss: 0.087296, Val Loss: 0.123483
# Epoch [118/300], Train Loss: 0.088858, Val Loss: 0.124366
# Epoch [119/300], Train Loss: 0.089622, Val Loss: 0.120280
# Epoch [120/300], Train Loss: 0.089632, Val Loss: 0.131976
# Epoch [121/300], Train Loss: 0.088381, Val Loss: 0.121868
# Epoch [122/300], Train Loss: 0.088399, Val Loss: 0.120205
# Epoch [123/300], Train Loss: 0.086994, Val Loss: 0.120307
# Epoch [124/300], Train Loss: 0.085276, Val Loss: 0.122250
# Epoch [125/300], Train Loss: 0.087394, Val Loss: 0.118645
# Epoch [126/300], Train Loss: 0.090208, Val Loss: 0.118132
# Epoch [127/300], Train Loss: 0.084038, Val Loss: 0.117885
# Epoch [128/300], Train Loss: 0.085920, Val Loss: 0.118509
# Epoch [129/300], Train Loss: 0.082649, Val Loss: 0.116964
# Epoch [130/300], Train Loss: 0.083389, Val Loss: 0.118420
# Epoch [131/300], Train Loss: 0.083397, Val Loss: 0.123318
# Epoch [132/300], Train Loss: 0.085545, Val Loss: 0.118808
# Epoch [133/300], Train Loss: 0.084149, Val Loss: 0.126098
# Epoch [134/300], Train Loss: 0.085351, Val Loss: 0.120675
# Epoch [135/300], Train Loss: 0.084499, Val Loss: 0.118118
# Epoch [136/300], Train Loss: 0.080555, Val Loss: 0.115521
# Epoch [137/300], Train Loss: 0.082897, Val Loss: 0.125811
# Epoch [138/300], Train Loss: 0.083959, Val Loss: 0.118228
# Epoch [139/300], Train Loss: 0.087990, Val Loss: 0.117083
# Epoch [140/300], Train Loss: 0.078989, Val Loss: 0.115460
# Epoch [141/300], Train Loss: 0.078994, Val Loss: 0.119095
# Epoch [142/300], Train Loss: 0.077699, Val Loss: 0.114626
# Epoch [143/300], Train Loss: 0.078150, Val Loss: 0.113908
# Epoch [144/300], Train Loss: 0.076450, Val Loss: 0.112827
# Epoch [145/300], Train Loss: 0.075632, Val Loss: 0.113526
# Epoch [146/300], Train Loss: 0.077489, Val Loss: 0.116805
# Epoch [147/300], Train Loss: 0.076968, Val Loss: 0.119885
# Epoch [148/300], Train Loss: 0.076883, Val Loss: 0.116688
# Epoch [149/300], Train Loss: 0.081615, Val Loss: 0.113102
# Epoch [150/300], Train Loss: 0.077484, Val Loss: 0.112857
# Epoch [151/300], Train Loss: 0.075305, Val Loss: 0.123730
# Epoch [152/300], Train Loss: 0.074539, Val Loss: 0.114215
# Epoch [153/300], Train Loss: 0.081747, Val Loss: 0.125306
# Epoch [154/300], Train Loss: 0.079151, Val Loss: 0.120171
# Epoch [155/300], Train Loss: 0.081453, Val Loss: 0.112929
# Epoch [156/300], Train Loss: 0.074050, Val Loss: 0.109997
# Epoch [157/300], Train Loss: 0.075269, Val Loss: 0.118247
# Epoch [158/300], Train Loss: 0.078452, Val Loss: 0.114128
# Epoch [159/300], Train Loss: 0.071976, Val Loss: 0.109167
# Epoch [160/300], Train Loss: 0.073279, Val Loss: 0.115792
# Epoch [161/300], Train Loss: 0.072604, Val Loss: 0.110456
# Epoch [162/300], Train Loss: 0.070527, Val Loss: 0.112098
# Epoch [163/300], Train Loss: 0.070819, Val Loss: 0.109709
# Epoch [164/300], Train Loss: 0.071203, Val Loss: 0.124346
# Epoch [165/300], Train Loss: 0.080165, Val Loss: 0.111955
# Epoch [166/300], Train Loss: 0.072673, Val Loss: 0.114411
# Epoch [167/300], Train Loss: 0.075220, Val Loss: 0.112680
# Epoch [168/300], Train Loss: 0.078368, Val Loss: 0.112166
# Epoch [169/300], Train Loss: 0.072078, Val Loss: 0.108654
# Epoch [170/300], Train Loss: 0.068727, Val Loss: 0.112799
# Epoch [171/300], Train Loss: 0.070966, Val Loss: 0.121729
# Epoch [172/300], Train Loss: 0.074973, Val Loss: 0.129027
# Epoch [173/300], Train Loss: 0.071484, Val Loss: 0.113069
# Epoch [174/300], Train Loss: 0.074836, Val Loss: 0.115494
# Epoch [175/300], Train Loss: 0.068006, Val Loss: 0.107315
# Epoch [176/300], Train Loss: 0.068686, Val Loss: 0.108943
# Epoch [177/300], Train Loss: 0.067424, Val Loss: 0.106642
# Epoch [178/300], Train Loss: 0.067846, Val Loss: 0.108251
# Epoch [179/300], Train Loss: 0.071631, Val Loss: 0.118969
# Epoch [180/300], Train Loss: 0.073646, Val Loss: 0.115166
# Epoch [181/300], Train Loss: 0.069891, Val Loss: 0.112153
# Epoch [182/300], Train Loss: 0.069769, Val Loss: 0.108446
# Epoch [183/300], Train Loss: 0.067507, Val Loss: 0.105972
# Epoch [184/300], Train Loss: 0.066540, Val Loss: 0.106217
# Epoch [185/300], Train Loss: 0.070225, Val Loss: 0.117331
# Epoch [186/300], Train Loss: 0.074025, Val Loss: 0.108966
# Epoch [187/300], Train Loss: 0.067642, Val Loss: 0.104893
# Epoch [188/300], Train Loss: 0.067463, Val Loss: 0.109668
# Epoch [189/300], Train Loss: 0.067224, Val Loss: 0.108796
# Epoch [190/300], Train Loss: 0.071232, Val Loss: 0.110082
# Epoch [191/300], Train Loss: 0.068222, Val Loss: 0.108683
# Epoch [192/300], Train Loss: 0.065848, Val Loss: 0.103787
# Epoch [193/300], Train Loss: 0.063148, Val Loss: 0.105395
# Epoch [194/300], Train Loss: 0.069632, Val Loss: 0.115503
# Epoch [195/300], Train Loss: 0.067909, Val Loss: 0.109277
# Epoch [196/300], Train Loss: 0.070940, Val Loss: 0.109573
# Epoch [197/300], Train Loss: 0.066169, Val Loss: 0.105163
# Epoch [198/300], Train Loss: 0.065943, Val Loss: 0.111642
# Epoch [199/300], Train Loss: 0.069371, Val Loss: 0.113707
# Epoch [200/300], Train Loss: 0.065969, Val Loss: 0.109386
# Epoch [201/300], Train Loss: 0.065513, Val Loss: 0.105738
# Epoch [202/300], Train Loss: 0.062102, Val Loss: 0.103518
# Epoch [203/300], Train Loss: 0.064348, Val Loss: 0.106813
# Epoch [204/300], Train Loss: 0.064969, Val Loss: 0.103698
# Epoch [205/300], Train Loss: 0.068532, Val Loss: 0.109182
# Epoch [206/300], Train Loss: 0.066745, Val Loss: 0.103109
# Epoch [207/300], Train Loss: 0.062460, Val Loss: 0.110807
# Epoch [208/300], Train Loss: 0.065739, Val Loss: 0.107681
# Epoch [209/300], Train Loss: 0.066808, Val Loss: 0.108175
# Epoch [210/300], Train Loss: 0.064521, Val Loss: 0.104817
# Epoch [211/300], Train Loss: 0.061836, Val Loss: 0.102937
# Epoch [212/300], Train Loss: 0.061669, Val Loss: 0.103639
# Epoch [213/300], Train Loss: 0.064948, Val Loss: 0.110557
# Epoch [214/300], Train Loss: 0.063416, Val Loss: 0.110564
# Epoch [215/300], Train Loss: 0.069972, Val Loss: 0.112094
# Epoch [216/300], Train Loss: 0.064215, Val Loss: 0.103965
# Epoch [217/300], Train Loss: 0.060276, Val Loss: 0.105330
# Epoch [218/300], Train Loss: 0.059823, Val Loss: 0.101956
# Epoch [219/300], Train Loss: 0.062324, Val Loss: 0.112016
# Epoch [220/300], Train Loss: 0.064700, Val Loss: 0.103263
# Epoch [221/300], Train Loss: 0.060769, Val Loss: 0.109926
# Epoch [222/300], Train Loss: 0.065609, Val Loss: 0.106044
# Epoch [223/300], Train Loss: 0.062535, Val Loss: 0.103551
# Epoch [224/300], Train Loss: 0.061508, Val Loss: 0.102836
# Epoch [225/300], Train Loss: 0.060143, Val Loss: 0.103124
# Epoch [226/300], Train Loss: 0.058808, Val Loss: 0.102446
# Epoch [227/300], Train Loss: 0.062590, Val Loss: 0.116253
# Epoch [228/300], Train Loss: 0.062394, Val Loss: 0.105353
# Epoch [229/300], Train Loss: 0.071591, Val Loss: 0.106946
# Epoch [230/300], Train Loss: 0.065499, Val Loss: 0.110120
# Epoch [231/300], Train Loss: 0.062416, Val Loss: 0.101272
# Epoch [232/300], Train Loss: 0.058159, Val Loss: 0.101065
# Epoch [233/300], Train Loss: 0.059102, Val Loss: 0.101793
# Epoch [234/300], Train Loss: 0.063112, Val Loss: 0.115653
# Epoch [235/300], Train Loss: 0.064945, Val Loss: 0.106953
# Epoch [236/300], Train Loss: 0.060891, Val Loss: 0.102920
# Epoch [237/300], Train Loss: 0.057439, Val Loss: 0.105920
# Epoch [238/300], Train Loss: 0.062406, Val Loss: 0.102708
# Epoch [239/300], Train Loss: 0.058925, Val Loss: 0.101974
# Epoch [240/300], Train Loss: 0.056428, Val Loss: 0.100106
# Epoch [241/300], Train Loss: 0.056844, Val Loss: 0.101941
# Epoch [242/300], Train Loss: 0.061872, Val Loss: 0.102569
# Epoch [243/300], Train Loss: 0.056801, Val Loss: 0.100003
# Epoch [244/300], Train Loss: 0.055786, Val Loss: 0.102323
# Epoch [245/300], Train Loss: 0.059167, Val Loss: 0.102210
# Epoch [246/300], Train Loss: 0.062904, Val Loss: 0.115194
# Epoch [247/300], Train Loss: 0.059988, Val Loss: 0.101284
# Epoch [248/300], Train Loss: 0.055708, Val Loss: 0.100357
# Epoch [249/300], Train Loss: 0.061044, Val Loss: 0.101348
# Epoch [250/300], Train Loss: 0.056540, Val Loss: 0.100300
# Epoch [251/300], Train Loss: 0.058754, Val Loss: 0.107870
# Epoch [252/300], Train Loss: 0.058006, Val Loss: 0.099996
# Epoch [253/300], Train Loss: 0.056721, Val Loss: 0.099872
# Epoch [254/300], Train Loss: 0.055997, Val Loss: 0.110504
# Epoch [255/300], Train Loss: 0.063629, Val Loss: 0.101291
# Epoch [256/300], Train Loss: 0.057029, Val Loss: 0.102226
# Epoch [257/300], Train Loss: 0.055309, Val Loss: 0.100021
# Epoch [258/300], Train Loss: 0.053974, Val Loss: 0.099311
# Epoch [259/300], Train Loss: 0.058534, Val Loss: 0.105281
# Epoch [260/300], Train Loss: 0.058776, Val Loss: 0.100869
# Epoch [261/300], Train Loss: 0.056603, Val Loss: 0.101806
# Epoch [262/300], Train Loss: 0.054940, Val Loss: 0.102992
# Epoch [263/300], Train Loss: 0.056752, Val Loss: 0.100107
# Epoch [264/300], Train Loss: 0.056139, Val Loss: 0.101102
# Epoch [265/300], Train Loss: 0.057560, Val Loss: 0.104636
# Epoch [266/300], Train Loss: 0.063079, Val Loss: 0.105672
# Epoch [267/300], Train Loss: 0.058441, Val Loss: 0.100191
# Epoch [268/300], Train Loss: 0.054722, Val Loss: 0.098786
# Epoch [269/300], Train Loss: 0.054616, Val Loss: 0.100976
# Epoch [270/300], Train Loss: 0.061201, Val Loss: 0.113353
# Epoch [271/300], Train Loss: 0.059635, Val Loss: 0.103155
# Epoch [272/300], Train Loss: 0.055799, Val Loss: 0.100054
# Epoch [273/300], Train Loss: 0.054985, Val Loss: 0.101477
# Epoch [274/300], Train Loss: 0.059233, Val Loss: 0.100260
# Epoch [275/300], Train Loss: 0.057312, Val Loss: 0.105117
# Epoch [276/300], Train Loss: 0.058407, Val Loss: 0.101161
# Epoch [277/300], Train Loss: 0.055210, Val Loss: 0.099636
# Epoch [278/300], Train Loss: 0.052877, Val Loss: 0.100618
# Epoch [279/300], Train Loss: 0.052148, Val Loss: 0.098244
# Epoch [280/300], Train Loss: 0.052580, Val Loss: 0.099192
# Epoch [281/300], Train Loss: 0.057184, Val Loss: 0.100673
# Epoch [282/300], Train Loss: 0.056108, Val Loss: 0.099898
# Epoch [283/300], Train Loss: 0.058448, Val Loss: 0.115225
# Epoch [284/300], Train Loss: 0.056237, Val Loss: 0.099084
# Epoch [285/300], Train Loss: 0.054713, Val Loss: 0.100353
# Epoch [286/300], Train Loss: 0.054821, Val Loss: 0.101222
# Epoch [287/300], Train Loss: 0.052678, Val Loss: 0.101064
# Epoch [288/300], Train Loss: 0.058900, Val Loss: 0.101843
# Epoch [289/300], Train Loss: 0.054654, Val Loss: 0.099783
# Epoch [290/300], Train Loss: 0.052300, Val Loss: 0.101008
# Epoch [291/300], Train Loss: 0.053562, Val Loss: 0.098704
# Epoch [292/300], Train Loss: 0.053189, Val Loss: 0.098443
# Epoch [293/300], Train Loss: 0.055623, Val Loss: 0.113388
# Epoch [294/300], Train Loss: 0.061129, Val Loss: 0.104264
# Epoch [295/300], Train Loss: 0.056664, Val Loss: 0.102675
# Epoch [296/300], Train Loss: 0.053379, Val Loss: 0.098053
# Epoch [297/300], Train Loss: 0.050746, Val Loss: 0.099810
# Epoch [298/300], Train Loss: 0.062420, Val Loss: 0.101353
# Epoch [299/300], Train Loss: 0.055635, Val Loss: 0.098073
# Epoch [300/300], Train Loss: 0.052017, Val Loss: 0.097080
# 训练完成！
# 正在评估RNN模型...
# 处理批次 1/8
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# 预测数据形状: (256, 2048, 1)
# 目标数据形状: (256, 2048, 1)
#
# === RNN模型评估结果 ===
# 模型参数数量: 4,005,825
# 模型类型: MultiRNN
# RNN层类型: ['RNN', 'GRU', 'LSTM', 'GRU', 'RNN', 'RNN']
# 隐藏层大小: [256, 512, 512, 256, 128, 64]
# RMSE:  3.565581
# MAE:   2.043586
# RRMSE: 52.4692%
# TRAC:  0.903125
# 相关系数R: 0.950329
#
# === 额外统计信息 ===
# 真实值均值: 0.000671
# 预测值均值: -0.020455
# 真实值标准差: 11.455333
# 预测值标准差: 10.908801
#
# 评估指标已保存到 rnn_evaluation_metrics.json
# 保存最佳RNN模型，验证损失: 0.097080
# 训练损失历史已保存到 rnn_loss_history.json
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# ...
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# === RNN模型复杂度分析 ===
# 总隐藏单元数: 1,728
# 网络层数: 6
# 平均隐藏层大小: 288.0
# 总参数量: 4,005,825
# 序列长度: 2048
#
# 所有任务完成！
# 生成的文件:
# - best_rnn_model.pth: 最佳模型权重
# - best_rnn_model_dwell.pth: 完整模型信息
# - rnn_evaluation_metrics.json: 评估指标
# - rnn_loss_history.json: 训练历史
# - rnn_training_loss.png: 损失曲线图
# - rnn_model_analysis.png: 模型分析图
# - strain_scaler.save: 应变数据标准化器
# - load_scaler.save: 载荷数据标准化器
#
# RNN模型特点:
# - 总参数量: 4,005,825
# - 模型类型: MultiRNN
# - 混合RNN架构: {'LSTM', 'RNN', 'GRU'}
# - 层数: 6
# - 序列建模能力强
# - 适合处理时序依赖关系

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
import joblib
from matplotlib import rcParams

# %%
# 设置中文字体（这里以SimHei字体为例）
rcParams['font.sans-serif'] = ['SimHei']  # 指定中文字体
rcParams['axes.unicode_minus'] = False  # 解决负号显示问题

# %%
# 1. 数据加载与预处理
def load_mat_files_from_directory(directory_path):
    """
    从指定目录加载所有.mat文件，并合并load_data和strain_data。
    
    参数:
        directory_path (str): .mat文件所在的目录路径。
        
    返回:
        load_list (list): 所有.mat文件中的load_data列表。
        strain_list (list): 所有.mat文件中的strain_data列表。
    """
    load_list = []
    strain_list = []
    
    # 遍历目录中的所有文件
    for filename in os.listdir(directory_path):
        if filename.endswith('.mat'):
            file_path = os.path.join(directory_path, filename)
            mat = scipy.io.loadmat(file_path)
            
            # 提取数据
            current_load = mat.get('load_data')
            current_strain = mat.get('strain_data')
            
            if current_load is None or current_strain is None:
                print(f"文件 {filename} 缺少 'load_data' 或 'strain_data'，已跳过。")
                continue
            
            load_list.append(current_load)
            strain_list.append(current_strain)
    
    if not load_list or not strain_list:
        raise ValueError("未找到任何包含 'load_data' 和 'strain_data' 的.mat文件。")
    
    # 合并所有加载的数据
    combined_load = np.concatenate(load_list, axis=1)  # 假设第二维是样本数
    combined_strain = np.concatenate(strain_list, axis=1)
    
    return combined_load, combined_strain

# %%
# 指定包含多个.mat文件的文件夹路径
mat_directory = r'/root/shared-nvme/SSH_remote/20250804LoadingIdentification/Data'  # 修改为您的文件夹路径

# 从文件夹中加载所有.mat文件的数据
combined_load_data, combined_strain_data = load_mat_files_from_directory(mat_directory)

# 转置数据，使时间为第一个维度
strain = combined_strain_data.T  # 形状: (总样本数, 10)
load = combined_load_data.T      # 形状: (总样本数, 1)

# 确保 load 是二维的，形状为 (样本数, 1)
if load.ndim > 2:
    load = load.squeeze()
if load.ndim == 1:
    load = load.reshape(-1, 1)
elif load.shape[1] != 1:
    load = load[:, 0:1]

# 标准化数据
strain_scaler = StandardScaler()
load_scaler = StandardScaler()

strain = strain_scaler.fit_transform(strain)  # 形状: (总样本数, 10)
load = load_scaler.fit_transform(load)        # 形状: (总样本数, 1)

# 保存scalers，以便后续使用
joblib.dump(strain_scaler, 'strain_scaler.save')
joblib.dump(load_scaler, 'load_scaler.save')
# Out:
# ['load_scaler.save']

# %%
current_path = os.getcwd()
print("当前 notebook 文件所在目录为:", current_path)
# Out:
# 当前 notebook 文件所在目录为: /root/shared-nvme/SSH_remote/20250804LoadingIdentification

# %%
# 2. 数据切片
def create_time_windows(data, window_size=2048, overlap=0.5):
    """
    将数据切分成时间窗口。
    
    参数:
        data (numpy.ndarray): 输入数据，形状为 (样本数, 特征数)。
        window_size (int): 每个窗口的大小。
        overlap (float): 窗口之间的重叠比例。
        
    返回:
        windows (numpy.ndarray): 切分后的数据，形状为 (窗口数, window_size, 特征数)。
    """
    step = int(window_size * (1 - overlap))
    num_samples = data.shape[0]
    num_features = data.shape[1]
    
    num_windows = (num_samples - window_size) // step + 1
    windows = np.zeros((num_windows, window_size, num_features))
    
    for i in range(num_windows):
        start = i * step
        end = start + window_size
        windows[i] = data[start:end]
    
    return windows

# 定义窗口大小和重叠比例
window_size = 2048
overlap = 0.5

# 切片应变数据和载荷数据
strain_windows = create_time_windows(strain, window_size=window_size, overlap=overlap)  # 形状: (num_windows, 2048, 10)
load_windows = create_time_windows(load, window_size=window_size, overlap=overlap)        # 形状: (num_windows, 2048, 1)

print(f'应变窗口形状: {strain_windows.shape}')  # 例如: (num_windows, 2048, 10)
print(f'载荷窗口形状: {load_windows.shape}')    # 例如: (num_windows, 2048, 1)

# 3. 创建数据集
class StrainLoadTimeDomainDataset(Dataset):
    def __init__(self, strain_windows, load_windows):
        self.strain = torch.tensor(strain_windows, dtype=torch.float32)  # 形状: (num_windows, 2048, 10)
        self.load = torch.tensor(load_windows, dtype=torch.float32)      # 形状: (num_windows, 2048, 1)

    def __len__(self):
        return self.strain.shape[0]

    def __getitem__(self, idx):
        # 返回应变序列和载荷序列
        strain_sample = self.strain[idx]  # 形状: (2048, 10)
        load_sample = self.load[idx]      # 形状: (2048, 1)
        return strain_sample, load_sample

# 拆分训练集和验证集
X_train, X_val, y_train, y_val = train_test_split(
    strain_windows, load_windows, test_size=0.2, random_state=42
)

# 创建数据集对象
train_dataset = StrainLoadTimeDomainDataset(X_train, y_train)
val_dataset = StrainLoadTimeDomainDataset(X_val, y_val)

# 创建数据加载器
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
# Out:
# 应变窗口形状: (1278, 2048, 10)
# 载荷窗口形状: (1278, 2048, 1)

# %%
# 4. 定义LSTM模型
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size, dropout=0.2):
        """
        初始化LSTM模型。    
        参数:
        - input_size: 输入特征的数量（应变数据的特征数，例如10）
        - hidden_size: LSTM隐藏层大小
        - num_layers: LSTM层数
        - output_size: 输出特征的数量（载荷数据的特征数，例如1）
        - dropout: dropout概率
        """
        super(LSTMModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        
        # 定义LSTM层
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout)
        
        # 定义全连接层
        self.fc = nn.Linear(hidden_size, output_size)
    
    def forward(self, x):
        # 初始化隐藏状态和细胞状态
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)  # (num_layers, batch_size, hidden_size)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        
        # 前向传播LSTM
        out, _ = self.lstm(x, (h0, c0))  # out: (batch_size, seq_length, hidden_size)
        
        # 通过全连接层
        out = self.fc(out)  # (batch_size, seq_length, output_size)
        return out

# 初始化模型参数
input_size = 10        # 应变数据的特征数量
hidden_size = 1024     # LSTM隐藏层大小，可以根据需要调整
num_layers = 4        # LSTM层数，可以根据需要调整
output_size = 1        # 载荷数据的特征数量

# 实例化模型
model = LSTMModel(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, output_size=output_size)

# 移动模型到GPU（如果可用）
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

# 定义损失函数和优化器
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# 5. 训练与验证流程
num_epochs = 300  # 根据需要调整
best_val_loss = float('inf')
patience = 100  # 早停耐心值
counter = 0

for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    
    for batch_idx, (strain, load) in enumerate(train_loader):
        strain = strain.to(device)  # 形状: (batch_size, 2048, 10)
        load = load.to(device)      # 形状: (batch_size, 2048, 1)
        
        # 前向传播
        outputs = model(strain)     # 形状: (batch_size, 2048, 1)
        loss = criterion(outputs, load)
        
        # 反向传播和优化
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item() * strain.size(0)
    
    avg_train_loss = train_loss / len(train_loader.dataset)
    
    # 验证
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for strain, load in val_loader:
            strain = strain.to(device)
            load = load.to(device)
            
            outputs = model(strain)
            loss = criterion(outputs, load)
            val_loss += loss.item() * strain.size(0)
    
    avg_val_loss = val_loss / len(val_loader.dataset)
    
    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {avg_train_loss:.6f}, Val Loss: {avg_val_loss:.6f}')
    
    # 早停检查
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        counter = 0
        # 保存最好的模型
        torch.save(model.state_dict(), 'best_lstm_model.pth')
    else:
        counter += 1
        if counter >= patience:
            print("早停触发！")
            break

print("训练完成！")

# 6. 载入最好的模型（如果需要）
model.load_state_dict(torch.load('best_lstm_model.pth'))

# 7. 评估模型
model.eval()
test_losses = []
with torch.no_grad():
    for strain, load in val_loader:
        strain = strain.to(device)
        load = load.to(device)
        
        outputs = model(strain)
        loss = criterion(outputs, load)
        test_losses.append(loss.item())
        
avg_test_loss = np.mean(test_losses)
print(f'验证集的平均损失: {avg_test_loss:.6f}')
# Out:
# Epoch [1/300], Train Loss: 0.981813, Val Loss: 0.932280
# Epoch [2/300], Train Loss: 0.897931, Val Loss: 0.842820
# Epoch [3/300], Train Loss: 0.800928, Val Loss: 0.790793
# Epoch [4/300], Train Loss: 0.772778, Val Loss: 0.756038
# Epoch [5/300], Train Loss: 0.761952, Val Loss: 0.751987
# Epoch [6/300], Train Loss: 0.751988, Val Loss: 0.708823
# Epoch [7/300], Train Loss: 0.689671, Val Loss: 0.744446
# Epoch [8/300], Train Loss: 0.718903, Val Loss: 0.865800
# Epoch [9/300], Train Loss: 0.770398, Val Loss: 0.670206
# Epoch [10/300], Train Loss: 0.686876, Val Loss: 0.687222
# Epoch [11/300], Train Loss: 0.651275, Val Loss: 0.612690
# Epoch [12/300], Train Loss: 0.615368, Val Loss: 0.584458
# Epoch [13/300], Train Loss: 0.578804, Val Loss: 0.566844
# Epoch [14/300], Train Loss: 0.569526, Val Loss: 0.588872
# Epoch [15/300], Train Loss: 0.552513, Val Loss: 0.540460
# Epoch [16/300], Train Loss: 0.545384, Val Loss: 0.548807
# Epoch [17/300], Train Loss: 0.565772, Val Loss: 0.616842
# Epoch [18/300], Train Loss: 0.527344, Val Loss: 0.498050
# Epoch [19/300], Train Loss: 0.491506, Val Loss: 0.493437
# Epoch [20/300], Train Loss: 0.473408, Val Loss: 0.473515
# Epoch [21/300], Train Loss: 0.451021, Val Loss: 0.457991
# Epoch [22/300], Train Loss: 0.481471, Val Loss: 0.475116
# Epoch [23/300], Train Loss: 0.444358, Val Loss: 0.459828
# Epoch [24/300], Train Loss: 0.447266, Val Loss: 0.460871
# Epoch [25/300], Train Loss: 0.446097, Val Loss: 0.422718
# Epoch [26/300], Train Loss: 0.390402, Val Loss: 0.397709
# Epoch [27/300], Train Loss: 0.365141, Val Loss: 0.387651
# Epoch [28/300], Train Loss: 0.351926, Val Loss: 0.404072
# Epoch [29/300], Train Loss: 0.358639, Val Loss: 0.405999
# Epoch [30/300], Train Loss: 0.338866, Val Loss: 0.363551
# Epoch [31/300], Train Loss: 0.326443, Val Loss: 0.366375
# Epoch [32/300], Train Loss: 0.328848, Val Loss: 0.371710
# Epoch [33/300], Train Loss: 0.337465, Val Loss: 0.337493
# Epoch [34/300], Train Loss: 0.270854, Val Loss: 0.303335
# Epoch [35/300], Train Loss: 0.243084, Val Loss: 0.307566
# Epoch [36/300], Train Loss: 0.230398, Val Loss: 0.276692
# Epoch [37/300], Train Loss: 0.218019, Val Loss: 0.267629
# Epoch [38/300], Train Loss: 0.206558, Val Loss: 0.258800
# Epoch [39/300], Train Loss: 0.190211, Val Loss: 0.247980
# Epoch [40/300], Train Loss: 0.190913, Val Loss: 0.247650
# Epoch [41/300], Train Loss: 0.173540, Val Loss: 0.230701
# Epoch [42/300], Train Loss: 0.155450, Val Loss: 0.214416
# Epoch [43/300], Train Loss: 0.146887, Val Loss: 0.207577
# Epoch [44/300], Train Loss: 0.132887, Val Loss: 0.205020
# Epoch [45/300], Train Loss: 0.129599, Val Loss: 0.192605
# Epoch [46/300], Train Loss: 0.119559, Val Loss: 0.188700
# Epoch [47/300], Train Loss: 0.118580, Val Loss: 0.186964
# Epoch [48/300], Train Loss: 0.110514, Val Loss: 0.178700
# Epoch [49/300], Train Loss: 0.105966, Val Loss: 0.170995
# Epoch [50/300], Train Loss: 0.098028, Val Loss: 0.171857
# Epoch [51/300], Train Loss: 0.096677, Val Loss: 0.163126
# Epoch [52/300], Train Loss: 0.086922, Val Loss: 0.157509
# Epoch [53/300], Train Loss: 0.081779, Val Loss: 0.155079
# Epoch [54/300], Train Loss: 0.080369, Val Loss: 0.155867
# Epoch [55/300], Train Loss: 0.085495, Val Loss: 0.164701
# Epoch [56/300], Train Loss: 0.081263, Val Loss: 0.150604
# Epoch [57/300], Train Loss: 0.073126, Val Loss: 0.143500
# Epoch [58/300], Train Loss: 0.067245, Val Loss: 0.141875
# Epoch [59/300], Train Loss: 0.062281, Val Loss: 0.136708
# Epoch [60/300], Train Loss: 0.058723, Val Loss: 0.135889
# Epoch [61/300], Train Loss: 0.056277, Val Loss: 0.133374
# Epoch [62/300], Train Loss: 0.053580, Val Loss: 0.130285
# Epoch [63/300], Train Loss: 0.051911, Val Loss: 0.130393
# Epoch [64/300], Train Loss: 0.050641, Val Loss: 0.128499
# Epoch [65/300], Train Loss: 0.050081, Val Loss: 0.128607
# Epoch [66/300], Train Loss: 0.049124, Val Loss: 0.128243
# Epoch [67/300], Train Loss: 0.049191, Val Loss: 0.128321
# Epoch [68/300], Train Loss: 0.047136, Val Loss: 0.128750
# Epoch [69/300], Train Loss: 0.046202, Val Loss: 0.127705
# Epoch [70/300], Train Loss: 0.074821, Val Loss: 0.158604
# Epoch [71/300], Train Loss: 0.073291, Val Loss: 0.135825
# Epoch [72/300], Train Loss: 0.051258, Val Loss: 0.125469
# Epoch [73/300], Train Loss: 0.043249, Val Loss: 0.125637
# Epoch [74/300], Train Loss: 0.041693, Val Loss: 0.120348
# Epoch [75/300], Train Loss: 0.038255, Val Loss: 0.118408
# Epoch [76/300], Train Loss: 0.036670, Val Loss: 0.118250
# Epoch [77/300], Train Loss: 0.035735, Val Loss: 0.116769
# Epoch [78/300], Train Loss: 0.035844, Val Loss: 0.120191
# Epoch [79/300], Train Loss: 0.035494, Val Loss: 0.115788
# Epoch [80/300], Train Loss: 0.034324, Val Loss: 0.115620
# Epoch [81/300], Train Loss: 0.034945, Val Loss: 0.117652
# Epoch [82/300], Train Loss: 0.033424, Val Loss: 0.114375
# Epoch [83/300], Train Loss: 0.031928, Val Loss: 0.114128
# Epoch [84/300], Train Loss: 0.031599, Val Loss: 0.114300
# Epoch [85/300], Train Loss: 0.031672, Val Loss: 0.113932
# Epoch [86/300], Train Loss: 0.033771, Val Loss: 0.116963
# Epoch [87/300], Train Loss: 0.033108, Val Loss: 0.115842
# Epoch [88/300], Train Loss: 0.030867, Val Loss: 0.119695
# Epoch [89/300], Train Loss: 0.039705, Val Loss: 0.115799
# Epoch [90/300], Train Loss: 0.032794, Val Loss: 0.128460
# Epoch [91/300], Train Loss: 0.038195, Val Loss: 0.117006
# Epoch [92/300], Train Loss: 0.034905, Val Loss: 0.113667
# Epoch [93/300], Train Loss: 0.029710, Val Loss: 0.110952
# Epoch [94/300], Train Loss: 0.027166, Val Loss: 0.109896
# Epoch [95/300], Train Loss: 0.026186, Val Loss: 0.108567
# Epoch [96/300], Train Loss: 0.026595, Val Loss: 0.110456
# Epoch [97/300], Train Loss: 0.025662, Val Loss: 0.108792
# Epoch [98/300], Train Loss: 0.025703, Val Loss: 0.109334
# Epoch [99/300], Train Loss: 0.024850, Val Loss: 0.109294
# Epoch [100/300], Train Loss: 0.024500, Val Loss: 0.109474
# Epoch [101/300], Train Loss: 0.024221, Val Loss: 0.107733
# Epoch [102/300], Train Loss: 0.024313, Val Loss: 0.108633
# Epoch [103/300], Train Loss: 0.024170, Val Loss: 0.107560
# Epoch [104/300], Train Loss: 0.023700, Val Loss: 0.108320
# Epoch [105/300], Train Loss: 0.024986, Val Loss: 0.109503
# Epoch [106/300], Train Loss: 0.023717, Val Loss: 0.109032
# Epoch [107/300], Train Loss: 0.022556, Val Loss: 0.106405
# Epoch [108/300], Train Loss: 0.022581, Val Loss: 0.106117
# Epoch [109/300], Train Loss: 0.022347, Val Loss: 0.106032
# Epoch [110/300], Train Loss: 0.022482, Val Loss: 0.106136
# Epoch [111/300], Train Loss: 0.021589, Val Loss: 0.106008
# Epoch [112/300], Train Loss: 0.021875, Val Loss: 0.107337
# Epoch [113/300], Train Loss: 0.022581, Val Loss: 0.107860
# Epoch [114/300], Train Loss: 0.022223, Val Loss: 0.108662
# Epoch [115/300], Train Loss: 0.022488, Val Loss: 0.106652
# Epoch [116/300], Train Loss: 0.021910, Val Loss: 0.109232
# Epoch [117/300], Train Loss: 0.022160, Val Loss: 0.105704
# Epoch [118/300], Train Loss: 0.025292, Val Loss: 0.113737
# Epoch [119/300], Train Loss: 0.026803, Val Loss: 0.108716
# Epoch [120/300], Train Loss: 0.025769, Val Loss: 0.112767
# Epoch [121/300], Train Loss: 0.025064, Val Loss: 0.105426
# Epoch [122/300], Train Loss: 0.020920, Val Loss: 0.104669
# Epoch [123/300], Train Loss: 0.019052, Val Loss: 0.103630
# Epoch [124/300], Train Loss: 0.018713, Val Loss: 0.103055
# Epoch [125/300], Train Loss: 0.018531, Val Loss: 0.103145
# Epoch [126/300], Train Loss: 0.018070, Val Loss: 0.102397
# Epoch [127/300], Train Loss: 0.018066, Val Loss: 0.105236
# Epoch [128/300], Train Loss: 0.020713, Val Loss: 0.103481
# Epoch [129/300], Train Loss: 0.019688, Val Loss: 0.105986
# Epoch [130/300], Train Loss: 0.019120, Val Loss: 0.103963
# Epoch [131/300], Train Loss: 0.017893, Val Loss: 0.102697
# Epoch [132/300], Train Loss: 0.018157, Val Loss: 0.103980
# Epoch [133/300], Train Loss: 0.019087, Val Loss: 0.102279
# Epoch [134/300], Train Loss: 0.018178, Val Loss: 0.107004
# Epoch [135/300], Train Loss: 0.022932, Val Loss: 0.112334
# Epoch [136/300], Train Loss: 0.022555, Val Loss: 0.104386
# Epoch [137/300], Train Loss: 0.018475, Val Loss: 0.103697
# Epoch [138/300], Train Loss: 0.018698, Val Loss: 0.103812
# Epoch [139/300], Train Loss: 0.019983, Val Loss: 0.103313
# Epoch [140/300], Train Loss: 0.018216, Val Loss: 0.103688
# Epoch [141/300], Train Loss: 0.017467, Val Loss: 0.101932
# Epoch [142/300], Train Loss: 0.016267, Val Loss: 0.101379
# Epoch [143/300], Train Loss: 0.015864, Val Loss: 0.101759
# Epoch [144/300], Train Loss: 0.024555, Val Loss: 0.115338
# Epoch [145/300], Train Loss: 0.035755, Val Loss: 0.118758
# Epoch [146/300], Train Loss: 0.026039, Val Loss: 0.107750
# Epoch [147/300], Train Loss: 0.020205, Val Loss: 0.102562
# Epoch [148/300], Train Loss: 0.016508, Val Loss: 0.100576
# Epoch [149/300], Train Loss: 0.015303, Val Loss: 0.100425
# Epoch [150/300], Train Loss: 0.015141, Val Loss: 0.100047
# Epoch [151/300], Train Loss: 0.014934, Val Loss: 0.099915
# Epoch [152/300], Train Loss: 0.014093, Val Loss: 0.099398
# Epoch [153/300], Train Loss: 0.013978, Val Loss: 0.099201
# Epoch [154/300], Train Loss: 0.014065, Val Loss: 0.099198
# Epoch [155/300], Train Loss: 0.014100, Val Loss: 0.099217
# Epoch [156/300], Train Loss: 0.013727, Val Loss: 0.099909
# Epoch [157/300], Train Loss: 0.013777, Val Loss: 0.099143
# Epoch [158/300], Train Loss: 0.013997, Val Loss: 0.099955
# Epoch [159/300], Train Loss: 0.013703, Val Loss: 0.099545
# Epoch [160/300], Train Loss: 0.013635, Val Loss: 0.099039
# Epoch [161/300], Train Loss: 0.013544, Val Loss: 0.100099
# Epoch [162/300], Train Loss: 0.014065, Val Loss: 0.101295
# Epoch [163/300], Train Loss: 0.015491, Val Loss: 0.101077
# Epoch [164/300], Train Loss: 0.014906, Val Loss: 0.100260
# Epoch [165/300], Train Loss: 0.013798, Val Loss: 0.100423
# Epoch [166/300], Train Loss: 0.018557, Val Loss: 0.106036
# Epoch [167/300], Train Loss: 0.017961, Val Loss: 0.102752
# Epoch [168/300], Train Loss: 0.015337, Val Loss: 0.099685
# Epoch [169/300], Train Loss: 0.013890, Val Loss: 0.099939
# Epoch [170/300], Train Loss: 0.013156, Val Loss: 0.098887
# Epoch [171/300], Train Loss: 0.012642, Val Loss: 0.098602
# Epoch [172/300], Train Loss: 0.012519, Val Loss: 0.099121
# Epoch [173/300], Train Loss: 0.012766, Val Loss: 0.098585
# Epoch [174/300], Train Loss: 0.012716, Val Loss: 0.098135
# Epoch [175/300], Train Loss: 0.012540, Val Loss: 0.098271
# Epoch [176/300], Train Loss: 0.012590, Val Loss: 0.098907
# Epoch [177/300], Train Loss: 0.012669, Val Loss: 0.098464
# Epoch [178/300], Train Loss: 0.013098, Val Loss: 0.098956
# Epoch [179/300], Train Loss: 0.018563, Val Loss: 0.105178
# Epoch [180/300], Train Loss: 0.027653, Val Loss: 0.109990
# Epoch [181/300], Train Loss: 0.021402, Val Loss: 0.104420
# Epoch [182/300], Train Loss: 0.016789, Val Loss: 0.101026
# Epoch [183/300], Train Loss: 0.013760, Val Loss: 0.101285
# Epoch [184/300], Train Loss: 0.013114, Val Loss: 0.098177
# Epoch [185/300], Train Loss: 0.012435, Val Loss: 0.098289
# Epoch [186/300], Train Loss: 0.011798, Val Loss: 0.099560
# Epoch [187/300], Train Loss: 0.013865, Val Loss: 0.100360
# Epoch [188/300], Train Loss: 0.013050, Val Loss: 0.099318
# Epoch [189/300], Train Loss: 0.015364, Val Loss: 0.102787
# Epoch [190/300], Train Loss: 0.014108, Val Loss: 0.098984
# Epoch [191/300], Train Loss: 0.012376, Val Loss: 0.098328
# Epoch [192/300], Train Loss: 0.011294, Val Loss: 0.098120
# Epoch [193/300], Train Loss: 0.011056, Val Loss: 0.096928
# Epoch [194/300], Train Loss: 0.011026, Val Loss: 0.100165
# Epoch [195/300], Train Loss: 0.012555, Val Loss: 0.098342
# Epoch [196/300], Train Loss: 0.011843, Val Loss: 0.098090
# Epoch [197/300], Train Loss: 0.011989, Val Loss: 0.098044
# Epoch [198/300], Train Loss: 0.011443, Val Loss: 0.097309
# Epoch [199/300], Train Loss: 0.011701, Val Loss: 0.097932
# Epoch [200/300], Train Loss: 0.011673, Val Loss: 0.099100
# Epoch [201/300], Train Loss: 0.011612, Val Loss: 0.099309
# Epoch [202/300], Train Loss: 0.014097, Val Loss: 0.100972
# Epoch [203/300], Train Loss: 0.018133, Val Loss: 0.103572
# Epoch [204/300], Train Loss: 0.015257, Val Loss: 0.100322
# Epoch [205/300], Train Loss: 0.012296, Val Loss: 0.098819
# Epoch [206/300], Train Loss: 0.011055, Val Loss: 0.096974
# Epoch [207/300], Train Loss: 0.010469, Val Loss: 0.097663
# Epoch [208/300], Train Loss: 0.010437, Val Loss: 0.097112
# Epoch [209/300], Train Loss: 0.010112, Val Loss: 0.096342
# Epoch [210/300], Train Loss: 0.010231, Val Loss: 0.097463
# Epoch [211/300], Train Loss: 0.010365, Val Loss: 0.096936
# Epoch [212/300], Train Loss: 0.010114, Val Loss: 0.096696
# Epoch [213/300], Train Loss: 0.010388, Val Loss: 0.097002
# Epoch [214/300], Train Loss: 0.010775, Val Loss: 0.098273
# Epoch [215/300], Train Loss: 0.010771, Val Loss: 0.097628
# Epoch [216/300], Train Loss: 0.011514, Val Loss: 0.098189
# Epoch [217/300], Train Loss: 0.020641, Val Loss: 0.108959
# Epoch [218/300], Train Loss: 0.018318, Val Loss: 0.100991
# Epoch [219/300], Train Loss: 0.012977, Val Loss: 0.098437
# Epoch [220/300], Train Loss: 0.011034, Val Loss: 0.097167
# Epoch [221/300], Train Loss: 0.010528, Val Loss: 0.096989
# Epoch [222/300], Train Loss: 0.010041, Val Loss: 0.096439
# Epoch [223/300], Train Loss: 0.009626, Val Loss: 0.095917
# Epoch [224/300], Train Loss: 0.009478, Val Loss: 0.096154
# Epoch [225/300], Train Loss: 0.009304, Val Loss: 0.095674
# Epoch [226/300], Train Loss: 0.009367, Val Loss: 0.096322
# Epoch [227/300], Train Loss: 0.010157, Val Loss: 0.096774
# Epoch [228/300], Train Loss: 0.010810, Val Loss: 0.097470
# Epoch [229/300], Train Loss: 0.013068, Val Loss: 0.099309
# Epoch [230/300], Train Loss: 0.013021, Val Loss: 0.098622
# Epoch [231/300], Train Loss: 0.011270, Val Loss: 0.098971
# Epoch [232/300], Train Loss: 0.010735, Val Loss: 0.097336
# Epoch [233/300], Train Loss: 0.010049, Val Loss: 0.096573
# Epoch [234/300], Train Loss: 0.009649, Val Loss: 0.095911
# Epoch [235/300], Train Loss: 0.009275, Val Loss: 0.096624
# Epoch [236/300], Train Loss: 0.009256, Val Loss: 0.096260
# Epoch [237/300], Train Loss: 0.009318, Val Loss: 0.097202
# Epoch [238/300], Train Loss: 0.009851, Val Loss: 0.097614
# Epoch [239/300], Train Loss: 0.010217, Val Loss: 0.098996
# Epoch [240/300], Train Loss: 0.011206, Val Loss: 0.096599
# Epoch [241/300], Train Loss: 0.010131, Val Loss: 0.096780
# Epoch [242/300], Train Loss: 0.014882, Val Loss: 0.103209
# Epoch [243/300], Train Loss: 0.014349, Val Loss: 0.099186
# Epoch [244/300], Train Loss: 0.011662, Val Loss: 0.098699
# Epoch [245/300], Train Loss: 0.009651, Val Loss: 0.097700
# Epoch [246/300], Train Loss: 0.009241, Val Loss: 0.095613
# Epoch [247/300], Train Loss: 0.008714, Val Loss: 0.095534
# Epoch [248/300], Train Loss: 0.008521, Val Loss: 0.095449
# Epoch [249/300], Train Loss: 0.008642, Val Loss: 0.097622
# Epoch [250/300], Train Loss: 0.012870, Val Loss: 0.098426
# Epoch [251/300], Train Loss: 0.011140, Val Loss: 0.098353
# Epoch [252/300], Train Loss: 0.009935, Val Loss: 0.097007
# Epoch [253/300], Train Loss: 0.008914, Val Loss: 0.095538
# Epoch [254/300], Train Loss: 0.008639, Val Loss: 0.095420
# Epoch [255/300], Train Loss: 0.008529, Val Loss: 0.095773
# Epoch [256/300], Train Loss: 0.008394, Val Loss: 0.095483
# Epoch [257/300], Train Loss: 0.008403, Val Loss: 0.095340
# Epoch [258/300], Train Loss: 0.008497, Val Loss: 0.095464
# Epoch [259/300], Train Loss: 0.009003, Val Loss: 0.095931
# Epoch [260/300], Train Loss: 0.009174, Val Loss: 0.095579
# Epoch [261/300], Train Loss: 0.008653, Val Loss: 0.095573
# Epoch [262/300], Train Loss: 0.008507, Val Loss: 0.095525
# Epoch [263/300], Train Loss: 0.008568, Val Loss: 0.095524
# Epoch [264/300], Train Loss: 0.009782, Val Loss: 0.096751
# Epoch [265/300], Train Loss: 0.009310, Val Loss: 0.096648
# Epoch [266/300], Train Loss: 0.009019, Val Loss: 0.095757
# Epoch [267/300], Train Loss: 0.008747, Val Loss: 0.095960
# Epoch [268/300], Train Loss: 0.009035, Val Loss: 0.097123
# Epoch [269/300], Train Loss: 0.008854, Val Loss: 0.096232
# Epoch [270/300], Train Loss: 0.010704, Val Loss: 0.100433
# Epoch [271/300], Train Loss: 0.011631, Val Loss: 0.097891
# Epoch [272/300], Train Loss: 0.009352, Val Loss: 0.096594
# Epoch [273/300], Train Loss: 0.008961, Val Loss: 0.095551
# Epoch [274/300], Train Loss: 0.008432, Val Loss: 0.095828
# Epoch [275/300], Train Loss: 0.008347, Val Loss: 0.095419
# Epoch [276/300], Train Loss: 0.008121, Val Loss: 0.095630
# Epoch [277/300], Train Loss: 0.008536, Val Loss: 0.096038
# Epoch [278/300], Train Loss: 0.008458, Val Loss: 0.098189
# Epoch [279/300], Train Loss: 0.010496, Val Loss: 0.097620
# Epoch [280/300], Train Loss: 0.009605, Val Loss: 0.096118
# Epoch [281/300], Train Loss: 0.008532, Val Loss: 0.096566
# Epoch [282/300], Train Loss: 0.008566, Val Loss: 0.098367
# Epoch [283/300], Train Loss: 0.008367, Val Loss: 0.095321
# Epoch [284/300], Train Loss: 0.008050, Val Loss: 0.095496
# Epoch [285/300], Train Loss: 0.008038, Val Loss: 0.095774
# Epoch [286/300], Train Loss: 0.007895, Val Loss: 0.095231
# Epoch [287/300], Train Loss: 0.007826, Val Loss: 0.095691
# Epoch [288/300], Train Loss: 0.008380, Val Loss: 0.096164
# Epoch [289/300], Train Loss: 0.008476, Val Loss: 0.095860
# Epoch [290/300], Train Loss: 0.009453, Val Loss: 0.099397
# Epoch [291/300], Train Loss: 0.010057, Val Loss: 0.102693
# Epoch [292/300], Train Loss: 0.014755, Val Loss: 0.102121
# Epoch [293/300], Train Loss: 0.011821, Val Loss: 0.097413
# Epoch [294/300], Train Loss: 0.009457, Val Loss: 0.096610
# Epoch [295/300], Train Loss: 0.008267, Val Loss: 0.095365
# Epoch [296/300], Train Loss: 0.007732, Val Loss: 0.095533
# Epoch [297/300], Train Loss: 0.007556, Val Loss: 0.094872
# Epoch [298/300], Train Loss: 0.007514, Val Loss: 0.095823
# Epoch [299/300], Train Loss: 0.007607, Val Loss: 0.095560
# Epoch [300/300], Train Loss: 0.007442, Val Loss: 0.095046
# 训练完成！
# 验证集的平均损失: 0.094872

# %%
torch.save({
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
        }, 'best_lstm_model_dwell.pth')
print(f'保存最佳模型，验证损失: {best_val_loss:.6f}')
# Out:
# 保存最佳模型，验证损失: 0.094872

# %%
print(f'保存最佳模型，验证损失: {best_val_loss:.6f}')
#%%
# 在适当的位置调用，比如每个训练周期结束后
torch.cuda.empty_cache()
# Out:
# 保存最佳模型，验证损失: 0.094872

# %%
# 6. 载入最好的模型（如果需要）
model.load_state_dict(torch.load('best_lstm_model.pth'))

# 7. 定义评估指标
def calculate_metrics(y_true, y_pred):
    """
    计算预测指标：RMSE, MAE, RRMSE, TRAC
    
    参数:
        y_true: 真实值
        y_pred: 预测值
    
    返回:
        dict: 包含各项指标的字典
    """
    # 确保输入为numpy数组
    if torch.is_tensor(y_true):
        y_true = y_true.cpu().numpy()
    if torch.is_tensor(y_pred):
        y_pred = y_pred.cpu().numpy()
    
    # 展平数组以便计算
    y_true_flat = y_true.flatten()
    y_pred_flat = y_pred.flatten()
    
    # RMSE (Root Mean Square Error)
    rmse = np.sqrt(np.mean((y_true_flat - y_pred_flat) ** 2))
    
    # MAE (Mean Absolute Error)
    mae = np.mean(np.abs(y_true_flat - y_pred_flat))
    
    # RRMSE (Relative Root Mean Square Error)
    # RRMSE = RMSE / mean(|y_true|) * 100%
    mean_true = np.mean(np.abs(y_true_flat))
    rrmse = (rmse / mean_true) * 100 if mean_true != 0 else float('inf')
    
    # TRAC (Tracking Coefficient) - 通常指相关系数的平方
    correlation_matrix = np.corrcoef(y_true_flat, y_pred_flat)
    correlation = correlation_matrix[0, 1]
    trac = correlation ** 2  # R^2
    
    return {
        'RMSE': rmse,
        'MAE': mae,
        'RRMSE': rrmse,
        'TRAC': trac,
        'R': correlation  # 额外返回相关系数
    }

# 8. 评估模型
model.eval()
all_predictions = []
all_targets = []

print("正在评估模型...")
with torch.no_grad():
    for batch_idx, (strain, load) in enumerate(val_loader):
        strain = strain.to(device)
        load = load.to(device)
        
        outputs = model(strain)
        
        # 反标准化预测结果和真实值
        outputs_cpu = outputs.cpu()
        load_cpu = load.cpu()
        
        # 将数据reshape为(batch_size * seq_length, 1)以便反标准化
        outputs_reshaped = outputs_cpu.view(-1, 1)
        load_reshaped = load_cpu.view(-1, 1)
        
        # 反标准化
        outputs_denorm = load_scaler.inverse_transform(outputs_reshaped)
        load_denorm = load_scaler.inverse_transform(load_reshaped)
        
        # 重新reshape回原来的形状
        outputs_denorm = outputs_denorm.reshape(outputs_cpu.shape)
        load_denorm = load_denorm.reshape(load_cpu.shape)
        
        all_predictions.append(outputs_denorm)
        all_targets.append(load_denorm)
        
        if batch_idx % 10 == 0:
            print(f'处理批次 {batch_idx + 1}/{len(val_loader)}')

# 合并所有预测和目标
all_predictions = np.concatenate(all_predictions, axis=0)
all_targets = np.concatenate(all_targets, axis=0)

print(f'预测数据形状: {all_predictions.shape}')
print(f'目标数据形状: {all_targets.shape}')

# 计算评估指标
metrics = calculate_metrics(all_targets, all_predictions)

# 打印结果
print("\n=== 模型评估结果 ===")
print(f"RMSE:  {metrics['RMSE']:.6f}")
print(f"MAE:   {metrics['MAE']:.6f}")
print(f"RRMSE: {metrics['RRMSE']:.4f}%")
print(f"TRAC:  {metrics['TRAC']:.6f}")
print(f"相关系数R: {metrics['R']:.6f}")

# 额外计算一些统计信息
print(f"\n=== 额外统计信息 ===")
print(f"真实值均值: {np.mean(all_targets):.6f}")
print(f"预测值均值: {np.mean(all_predictions):.6f}")
print(f"真实值标准差: {np.std(all_targets):.6f}")
print(f"预测值标准差: {np.std(all_predictions):.6f}")

# 保存评估结果
metrics_save = {
    'RMSE': float(metrics['RMSE']),
    'MAE': float(metrics['MAE']),
    'RRMSE': float(metrics['RRMSE']),
    'TRAC': float(metrics['TRAC']),
    'R': float(metrics['R']),
    'mean_true': float(np.mean(all_targets)),
    'mean_pred': float(np.mean(all_predictions)),
    'std_true': float(np.std(all_targets)),
    'std_pred': float(np.std(all_predictions))
}

# 保存指标到文件
import json
with open('evaluation_metrics.json', 'w') as f:
    json.dump(metrics_save, f, indent=4)

print(f"\n评估指标已保存到 evaluation_metrics.json")
# Out:
# 正在评估模型...
# 处理批次 1/8
# 预测数据形状: (256, 2048, 1)
# 目标数据形状: (256, 2048, 1)
#
# === 模型评估结果 ===
# RMSE:  3.524799
# MAE:   1.417050
# RRMSE: 51.8691%
# TRAC:  0.905599
# 相关系数R: 0.951630
#
# === 额外统计信息 ===
# 真实值均值: 0.000671
# 预测值均值: -0.011703
# 真实值标准差: 11.455333
# 预测值标准差: 11.091949
#
# 评估指标已保存到 evaluation_metrics.json

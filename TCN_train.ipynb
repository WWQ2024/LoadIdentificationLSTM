# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
import joblib
import json
from matplotlib import rcParams

# 设置中文字体（这里以SimHei字体为例）
rcParams['font.sans-serif'] = ['SimHei']  # 指定中文字体
rcParams['axes.unicode_minus'] = False  # 解决负号显示问题

def load_mat_files_from_directory(directory_path):
    """
    从指定文件夹中加载所有.mat文件的数据
    
    参数:
        directory_path (str): 包含.mat文件的文件夹路径
    
    返回:
        tuple: (combined_load_data, combined_strain_data)
            - combined_load_data: 合并后的载荷数据
            - combined_strain_data: 合并后的应变数据
    """
    combined_load_data = []
    combined_strain_data = []
    
    # 获取文件夹中的所有.mat文件
    mat_files = [f for f in os.listdir(directory_path) if f.endswith('.mat')]
    mat_files.sort()  # 按文件名排序
    
    print(f"找到 {len(mat_files)} 个.mat文件")
    
    for mat_file in mat_files:
        file_path = os.path.join(directory_path, mat_file)
        print(f"正在加载: {mat_file}")
        
        try:
            # 加载.mat文件
            mat_data = scipy.io.loadmat(file_path)
            
            # 根据您的数据结构调整这些键名
            # 假设载荷数据的键名为'load'或'Load'，应变数据的键名为'strain'或'Strain'
            load_key = None
            strain_key = None
            
            # 查找可能的键名
            for key in mat_data.keys():
                if key.lower() in ['load', 'loads', 'force', 'forces']:
                    load_key = key
                elif key.lower() in ['strain', 'strains', 'displacement', 'displacements']:
                    strain_key = key
            
            # 如果没有找到标准键名，使用数据中的非私有键
            if load_key is None or strain_key is None:
                data_keys = [k for k in mat_data.keys() if not k.startswith('__')]
                if len(data_keys) >= 2:
                    load_key = data_keys[0]
                    strain_key = data_keys[1]
                    print(f"使用键名: load='{load_key}', strain='{strain_key}'")
            
            if load_key and strain_key:
                load_data = mat_data[load_key]
                strain_data = mat_data[strain_key]
                
                combined_load_data.append(load_data)
                combined_strain_data.append(strain_data)
                
                print(f"  载荷数据形状: {load_data.shape}")
                print(f"  应变数据形状: {strain_data.shape}")
            else:
                print(f"  警告: 无法在 {mat_file} 中找到载荷或应变数据")
                
        except Exception as e:
            print(f"  错误: 加载 {mat_file} 时出错: {e}")
    
    if combined_load_data and combined_strain_data:
        # 合并所有数据
        combined_load_data = np.concatenate(combined_load_data, axis=1)
        combined_strain_data = np.concatenate(combined_strain_data, axis=1)
        
        print(f"\n合并后的数据形状:")
        print(f"载荷数据: {combined_load_data.shape}")
        print(f"应变数据: {combined_strain_data.shape}")
        
        return combined_load_data, combined_strain_data
    else:
        raise ValueError("没有成功加载任何数据文件")

# 指定包含多个.mat文件的文件夹路径
mat_directory = r'/root/shared-nvme/SSH_remote/20250804LoadingIdentification/Data'  # 修改为您的文件夹路径

# 从文件夹中加载所有.mat文件的数据
combined_load_data, combined_strain_data = load_mat_files_from_directory(mat_directory)

# 转置数据，使时间为第一个维度
strain = combined_strain_data.T  # 形状: (总样本数, 10)
load = combined_load_data.T      # 形状: (总样本数, 1)

# 确保 load 是二维的，形状为 (样本数, 1)
if load.ndim > 2:
    load = load.squeeze()
if load.ndim == 1:
    load = load.reshape(-1, 1)
elif load.shape[1] != 1:
    load = load[:, 0:1]

# 标准化数据
strain_scaler = StandardScaler()
load_scaler = StandardScaler()

strain = strain_scaler.fit_transform(strain)  # 形状: (总样本数, 10)
load = load_scaler.fit_transform(load)        # 形状: (总样本数, 1)

# 保存scalers，以便后续使用
joblib.dump(strain_scaler, 'strain_scaler.save')
joblib.dump(load_scaler, 'load_scaler.save')
current_path = os.getcwd()
print("当前 notebook 文件所在目录为:", current_path)

# 2. 数据切片
def create_time_windows(data, window_size=2048, overlap=0.5):
    """
    将数据切分成时间窗口。
    
    参数:
        data (numpy.ndarray): 输入数据，形状为 (样本数, 特征数)。
        window_size (int): 每个窗口的大小。
        overlap (float): 窗口之间的重叠比例。
        
    返回:
        windows (numpy.ndarray): 切分后的数据，形状为 (窗口数, window_size, 特征数)。
    """
    step = int(window_size * (1 - overlap))
    num_samples = data.shape[0]
    num_features = data.shape[1]
    
    num_windows = (num_samples - window_size) // step + 1
    windows = np.zeros((num_windows, window_size, num_features))
    
    for i in range(num_windows):
        start = i * step
        end = start + window_size
        windows[i] = data[start:end]
    
    return windows

# 定义窗口大小和重叠比例
window_size = 2048
overlap = 0.5

# 切片应变数据和载荷数据
strain_windows = create_time_windows(strain, window_size=window_size, overlap=overlap)  # 形状: (num_windows, 2048, 10)
load_windows = create_time_windows(load, window_size=window_size, overlap=overlap)        # 形状: (num_windows, 2048, 1)

print(f'应变窗口形状: {strain_windows.shape}')  # 例如: (num_windows, 2048, 10)
print(f'载荷窗口形状: {load_windows.shape}')    # 例如: (num_windows, 2048, 1)

# 3. 创建数据集
class StrainLoadTimeDomainDataset(Dataset):
    def __init__(self, strain_windows, load_windows):
        self.strain = torch.tensor(strain_windows, dtype=torch.float32)  # 形状: (num_windows, 2048, 10)
        self.load = torch.tensor(load_windows, dtype=torch.float32)      # 形状: (num_windows, 2048, 1)

    def __len__(self):
        return self.strain.shape[0]

    def __getitem__(self, idx):
        # 返回应变序列和载荷序列
        strain_sample = self.strain[idx]  # 形状: (2048, 10)
        load_sample = self.load[idx]      # 形状: (2048, 1)
        return strain_sample, load_sample

# 拆分训练集和验证集
X_train, X_val, y_train, y_val = train_test_split(
    strain_windows, load_windows, test_size=0.2, random_state=42
)

# 创建数据集对象
train_dataset = StrainLoadTimeDomainDataset(X_train, y_train)
val_dataset = StrainLoadTimeDomainDataset(X_val, y_val)

# 创建数据加载器
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# 4. 定义TCN模型
class Chomp1d(nn.Module):
    def __init__(self, chomp_size):
        super(Chomp1d, self).__init__()
        self.chomp_size = chomp_size

    def forward(self, x):
        """
        裁剪操作，确保因果性
        """
        return x[:, :, :-self.chomp_size].contiguous()

class TemporalBlock(nn.Module):
    def __init__(self, n_inputs, n_outputs, kernel_size, stride, dilation, padding, dropout=0.2):
        """
        TCN的基本构建块
        
        参数:
        - n_inputs: 输入通道数
        - n_outputs: 输出通道数
        - kernel_size: 卷积核大小
        - stride: 步长
        - dilation: 膨胀率
        - padding: 填充
        - dropout: dropout概率
        """
        super(TemporalBlock, self).__init__()
        
        # 第一个卷积层
        self.conv1 = nn.Conv1d(n_inputs, n_outputs, kernel_size,
                               stride=stride, padding=padding, dilation=dilation)
        self.chomp1 = Chomp1d(padding)
        self.relu1 = nn.ReLU()
        self.dropout1 = nn.Dropout(dropout)

        # 第二个卷积层
        self.conv2 = nn.Conv1d(n_outputs, n_outputs, kernel_size,
                               stride=stride, padding=padding, dilation=dilation)
        self.chomp2 = Chomp1d(padding)
        self.relu2 = nn.ReLU()
        self.dropout2 = nn.Dropout(dropout)

        # 组合网络
        self.net = nn.Sequential(self.conv1, self.chomp1, self.relu1, self.dropout1,
                                 self.conv2, self.chomp2, self.relu2, self.dropout2)
        
        # 下采样层（如果输入输出通道数不同）
        self.downsample = nn.Conv1d(n_inputs, n_outputs, 1) if n_inputs != n_outputs else None
        
        # 最终的ReLU激活
        self.relu = nn.ReLU()
        
        # 初始化权重
        self.init_weights()

    def init_weights(self):
        """初始化卷积层权重"""
        self.conv1.weight.data.normal_(0, 0.01)
        self.conv2.weight.data.normal_(0, 0.01)
        if self.downsample is not None:
            self.downsample.weight.data.normal_(0, 0.01)

    def forward(self, x):
        """
        前向传播
        
        参数:
        - x: 输入张量，形状为 (batch_size, channels, seq_len)
        """
        out = self.net(x)
        res = x if self.downsample is None else self.downsample(x)
        return self.relu(out + res)

class TemporalConvNet(nn.Module):
    def __init__(self, num_inputs, num_channels, kernel_size=2, dropout=0.2):
        """
        时间卷积网络
        
        参数:
        - num_inputs: 输入特征数
        - num_channels: 每层的通道数列表
        - kernel_size: 卷积核大小
        - dropout: dropout概率
        """
        super(TemporalConvNet, self).__init__()
        layers = []
        num_levels = len(num_channels)
        
        for i in range(num_levels):
            dilation_size = 2 ** i
            in_channels = num_inputs if i == 0 else num_channels[i-1]
            out_channels = num_channels[i]
            
            layers += [TemporalBlock(in_channels, out_channels, kernel_size, stride=1, 
                                   dilation=dilation_size,
                                   padding=(kernel_size-1) * dilation_size, 
                                   dropout=dropout)]

        self.network = nn.Sequential(*layers)

    def forward(self, x):
        """
        前向传播
        
        参数:
        - x: 输入张量，形状为 (batch_size, channels, seq_len)
        """
        return self.network(x)

class TCNModel(nn.Module):
    def __init__(self, input_size, num_channels, output_size=1, kernel_size=3, dropout=0.2):
        """
        完整的TCN模型
        
        参数:
        - input_size: 输入特征数（应变数据的特征数，例如10）
        - num_channels: TCN各层的通道数列表
        - output_size: 输出特征数（载荷数据的特征数，例如1）
        - kernel_size: 卷积核大小
        - dropout: dropout概率
        """
        super(TCNModel, self).__init__()
        
        self.input_size = input_size
        self.output_size = output_size
        
        # TCN主干网络
        self.tcn = TemporalConvNet(input_size, num_channels, kernel_size, dropout)
        
        # 输出层
        self.linear = nn.Linear(num_channels[-1], output_size)
        
        # 初始化线性层权重
        self.init_weights()
    
    def init_weights(self):
        """初始化线性层权重"""
        self.linear.weight.data.normal_(0, 0.01)
    
    def forward(self, x):
        """
        前向传播
        
        参数:
        - x: 输入张量，形状为 (batch_size, seq_len, input_size)
        
        返回:
        - output: 输出张量，形状为 (batch_size, seq_len, output_size)
        """
        # 转换维度：(batch_size, seq_len, input_size) -> (batch_size, input_size, seq_len)
        x = x.transpose(1, 2)
        
        # TCN处理
        y = self.tcn(x)  # 形状: (batch_size, num_channels[-1], seq_len)
        
        # 转换回来：(batch_size, num_channels[-1], seq_len) -> (batch_size, seq_len, num_channels[-1])
        y = y.transpose(1, 2)
        
        # 通过线性层
        output = self.linear(y)  # 形状: (batch_size, seq_len, output_size)
        
        return output
    
    def count_parameters(self):
        """计算模型参数数量"""
        return sum(p.numel() for p in self.parameters() if p.requires_grad)

# 初始化模型参数
input_size = 10        # 应变数据的特征数量
output_size = 1        # 载荷数据的特征数量

# TCN参数设置（调整以匹配之前模型的参数量）
# 通过调整通道数和层数来控制参数量
num_channels = [64, 128, 256, 512, 512, 256, 128, 64]  # 8层TCN
kernel_size = 3        # 卷积核大小
dropout = 0.2         # Dropout率

# 实例化模型
model = TCNModel(
    input_size=input_size,
    num_channels=num_channels,
    output_size=output_size,
    kernel_size=kernel_size,
    dropout=dropout
)

# 打印模型参数数量
total_params = model.count_parameters()
print(f"TCN模型总参数数量: {total_params:,}")
print(f"模型结构:\n{model}")

# 移动模型到GPU（如果可用）
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
print(f"使用设备: {device}")

# 定义损失函数和优化器
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)  # TCN通常可以使用较高的学习率

# 学习率调度器
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=20, verbose=True)

# 5. 训练与验证流程
num_epochs = 300  # 根据需要调整
best_val_loss = float('inf')
patience = 100  # 早停耐心值
counter = 0

# 记录训练历史
train_losses = []
val_losses = []

print("开始训练TCN模型...")

for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    
    for batch_idx, (strain, load) in enumerate(train_loader):
        strain = strain.to(device)  # 形状: (batch_size, 2048, 10)
        load = load.to(device)      # 形状: (batch_size, 2048, 1)
        
        # 前向传播
        outputs = model(strain)     # 形状: (batch_size, 2048, 1)
        loss = criterion(outputs, load)
        
        # 反向传播和优化
        optimizer.zero_grad()
        loss.backward()
        
        # 梯度裁剪（防止梯度爆炸）
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        
        optimizer.step()
        
        train_loss += loss.item() * strain.size(0)
    
    avg_train_loss = train_loss / len(train_loader.dataset)
    train_losses.append(avg_train_loss)
    
    # 验证
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for strain, load in val_loader:
            strain = strain.to(device)
            load = load.to(device)
            
            outputs = model(strain)
            loss = criterion(outputs, load)
            val_loss += loss.item() * strain.size(0)
    
    avg_val_loss = val_loss / len(val_loader.dataset)
    val_losses.append(avg_val_loss)
    
    # 学习率调度
    scheduler.step(avg_val_loss)
    
    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {avg_train_loss:.6f}, Val Loss: {avg_val_loss:.6f}')
    
    # 早停检查
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        counter = 0
        # 保存最好的模型
        torch.save(model.state_dict(), 'best_tcn_model.pth')
    else:
        counter += 1
        if counter >= patience:
            print("早停触发！")
            break

print("训练完成！")

# 6. 载入最好的模型
model.load_state_dict(torch.load('best_tcn_model.pth'))

# 7. 定义评估指标
def calculate_metrics(y_true, y_pred):
    """
    计算预测指标：RMSE, MAE, RRMSE, TRAC
    
    参数:
        y_true: 真实值
        y_pred: 预测值
    
    返回:
        dict: 包含各项指标的字典
    """
    # 确保输入为numpy数组
    if torch.is_tensor(y_true):
        y_true = y_true.cpu().numpy()
    if torch.is_tensor(y_pred):
        y_pred = y_pred.cpu().numpy()
    
    # 展平数组以便计算
    y_true_flat = y_true.flatten()
    y_pred_flat = y_pred.flatten()
    
    # RMSE (Root Mean Square Error)
    rmse = np.sqrt(np.mean((y_true_flat - y_pred_flat) ** 2))
    
    # MAE (Mean Absolute Error)
    mae = np.mean(np.abs(y_true_flat - y_pred_flat))
    
    # RRMSE (Relative Root Mean Square Error)
    # RRMSE = RMSE / mean(|y_true|) * 100%
    mean_true = np.mean(np.abs(y_true_flat))
    rrmse = (rmse / mean_true) * 100 if mean_true != 0 else float('inf')
    
    # TRAC (Tracking Coefficient) - 通常指相关系数的平方
    correlation_matrix = np.corrcoef(y_true_flat, y_pred_flat)
    correlation = correlation_matrix[0, 1]
    trac = correlation ** 2  # R^2
    
    return {
        'RMSE': rmse,
        'MAE': mae,
        'RRMSE': rrmse,
        'TRAC': trac,
        'R': correlation  # 额外返回相关系数
    }

# 8. 评估模型
model.eval()
all_predictions = []
all_targets = []

print("正在评估TCN模型...")
with torch.no_grad():
    for batch_idx, (strain, load) in enumerate(val_loader):
        strain = strain.to(device)
        load = load.to(device)
        
        outputs = model(strain)
        
        # 反标准化预测结果和真实值
        outputs_cpu = outputs.cpu()
        load_cpu = load.cpu()
        
        # 将数据reshape为(batch_size * seq_length, 1)以便反标准化
        outputs_reshaped = outputs_cpu.view(-1, 1)
        load_reshaped = load_cpu.view(-1, 1)
        
        # 反标准化
        outputs_denorm = load_scaler.inverse_transform(outputs_reshaped)
        load_denorm = load_scaler.inverse_transform(load_reshaped)
        
        # 重新reshape回原来的形状
        outputs_denorm = outputs_denorm.reshape(outputs_cpu.shape)
        load_denorm = load_denorm.reshape(load_cpu.shape)
        
        all_predictions.append(outputs_denorm)
        all_targets.append(load_denorm)
        
        if batch_idx % 10 == 0:
            print(f'处理批次 {batch_idx + 1}/{len(val_loader)}')

# 合并所有预测和目标
all_predictions = np.concatenate(all_predictions, axis=0)
all_targets = np.concatenate(all_targets, axis=0)

print(f'预测数据形状: {all_predictions.shape}')
print(f'目标数据形状: {all_targets.shape}')

# 计算评估指标
metrics = calculate_metrics(all_targets, all_predictions)

# 打印结果
print("\n=== TCN模型评估结果 ===")
print(f"模型参数数量: {total_params:,}")
print(f"RMSE:  {metrics['RMSE']:.6f}")
print(f"MAE:   {metrics['MAE']:.6f}")
print(f"RRMSE: {metrics['RRMSE']:.4f}%")
print(f"TRAC:  {metrics['TRAC']:.6f}")
print(f"相关系数R: {metrics['R']:.6f}")

# 额外计算一些统计信息
print(f"\n=== 额外统计信息 ===")
print(f"真实值均值: {np.mean(all_targets):.6f}")
print(f"预测值均值: {np.mean(all_predictions):.6f}")
print(f"真实值标准差: {np.std(all_targets):.6f}")
print(f"预测值标准差: {np.std(all_predictions):.6f}")

# 保存评估结果
metrics_save = {
    'model_type': 'TCN',
    'total_params': int(total_params),
    'RMSE': float(metrics['RMSE']),
    'MAE': float(metrics['MAE']),
    'RRMSE': float(metrics['RRMSE']),
    'TRAC': float(metrics['TRAC']),
    'R': float(metrics['R']),
    'mean_true': float(np.mean(all_targets)),
    'mean_pred': float(np.mean(all_predictions)),
    'std_true': float(np.std(all_targets)),
    'std_pred': float(np.std(all_predictions)),
    'best_val_loss': float(best_val_loss)
}

# 保存指标到文件
with open('tcn_evaluation_metrics.json', 'w') as f:
    json.dump(metrics_save, f, indent=4)

print(f"\n评估指标已保存到 tcn_evaluation_metrics.json")

# 保存完整的模型和配置
torch.save({
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'model_config': {
        'input_size': input_size,
        'num_channels': num_channels,
        'output_size': output_size,
        'kernel_size': kernel_size,
        'dropout': dropout
    },
    'metrics': metrics_save,
    'total_params': total_params,
    'train_losses': train_losses,
    'val_losses': val_losses
}, 'best_tcn_model_dwell.pth')

print(f'保存最佳TCN模型，验证损失: {best_val_loss:.6f}')

# 保存训练损失历史
loss_history = {
    'train_losses': train_losses,
    'val_losses': val_losses,
    'epochs': list(range(1, len(train_losses) + 1))
}

with open('tcn_loss_history.json', 'w') as f:
    json.dump(loss_history, f, indent=4)

print("训练损失历史已保存到 tcn_loss_history.json")

# 绘制训练和验证损失曲线
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Training Loss', linewidth=2)
plt.plot(range(1, len(val_losses) + 1), val_losses, label='Validation Loss', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('TCN Model Training and Validation Loss')
plt.legend()
plt.grid(True, alpha=0.3)
plt.yscale('log')  # 使用对数尺度
plt.tight_layout()
plt.savefig('tcn_training_loss.png', dpi=300, bbox_inches='tight')
plt.show()

# 9. 可视化TCN模型的感受野
def calculate_receptive_field(num_channels, kernel_size):
    """
    计算TCN的感受野
    
    参数:
    - num_channels: 通道数列表
    - kernel_size: 卷积核大小
    
    返回:
    - receptive_field: 感受野大小
    """
    receptive_field = 1
    for i in range(len(num_channels)):
        dilation = 2 ** i
        receptive_field += (kernel_size - 1) * dilation
    return receptive_field

receptive_field = calculate_receptive_field(num_channels, kernel_size)
print(f"\nTCN模型感受野: {receptive_field} 个时间步")
print(f"相对于序列长度 {window_size} 的比例: {receptive_field/window_size:.2%}")

# 绘制模型架构信息
plt.figure(figsize=(12, 8))

# 子图1: 通道数变化
plt.subplot(2, 2, 1)
layers = list(range(len(num_channels)))
plt.bar(layers, num_channels, alpha=0.7, color='skyblue')
plt.xlabel('Layer')
plt.ylabel('Number of Channels')
plt.title('TCN Channels per Layer')
plt.grid(True, alpha=0.3)

# 子图2: 膨胀率变化
plt.subplot(2, 2, 2)
dilations = [2**i for i in range(len(num_channels))]
plt.bar(layers, dilations, alpha=0.7, color='lightcoral')
plt.xlabel('Layer')
plt.ylabel('Dilation Rate')
plt.title('TCN Dilation Rate per Layer')
plt.yscale('log')
plt.grid(True, alpha=0.3)

# 子图3: 累积感受野
plt.subplot(2, 2, 3)
cumulative_rf = []
rf = 1
for i in range(len(num_channels)):
    dilation = 2 ** i
    rf += (kernel_size - 1) * dilation
    cumulative_rf.append(rf)

plt.plot(layers, cumulative_rf, 'o-', linewidth=2, markersize=6, color='green')
plt.xlabel('Layer')
plt.ylabel('Cumulative Receptive Field')
plt.title('TCN Cumulative Receptive Field')
plt.grid(True, alpha=0.3)

# 子图4: 参数分布
plt.subplot(2, 2, 4)
param_counts = []
for name, param in model.named_parameters():
    if param.requires_grad:
        param_counts.append(param.numel())

param_names = [name.split('.')[0] for name, param in model.named_parameters() if param.requires_grad]
param_names_unique = []
param_counts_grouped = []
current_group = None
current_count = 0

for name, count in zip(param_names, param_counts):
    if name != current_group:
        if current_group is not None:
            param_names_unique.append(current_group)
            param_counts_grouped.append(current_count)
        current_group = name
        current_count = count
    else:
        current_count += count

# 添加最后一组
if current_group is not None:
    param_names_unique.append(current_group)
    param_counts_grouped.append(current_count)

plt.pie(param_counts_grouped, labels=param_names_unique, autopct='%1.1f%%', startangle=90)
plt.title('Parameter Distribution')

plt.tight_layout()
plt.savefig('tcn_model_analysis.png', dpi=300, bbox_inches='tight')
plt.show()

# 清理GPU缓存
torch.cuda.empty_cache()

print("\n所有任务完成！")
print("生成的文件:")
print("- best_tcn_model.pth: 最佳模型权重")
print("- best_tcn_model_dwell.pth: 完整模型信息")
print("- tcn_evaluation_metrics.json: 评估指标")
print("- tcn_loss_history.json: 训练历史")
print("- tcn_training_loss.png: 损失曲线图")
print("- tcn_model_analysis.png: 模型分析图")
print("- strain_scaler.save: 应变数据标准化器")
print("- load_scaler.save: 载荷数据标准化器")

print(f"\nTCN模型特点:")
print(f"- 总参数量: {total_params:,}")
print(f"- 网络层数: {len(num_channels)}")
print(f"- 感受野大小: {receptive_field}")
print(f"- 并行训练能力强")
print(f"- 计算效率高")
# Out:
# 找到 1 个.mat文件
# 正在加载: Load_Strain_random_normal.mat
# 使用键名: load='load_data', strain='strain_data'
#   载荷数据形状: (1, 1309696)
#   应变数据形状: (10, 1309696)
#
# 合并后的数据形状:
# 载荷数据: (1, 1309696)
# 应变数据: (10, 1309696)
# 当前 notebook 文件所在目录为: /root/shared-nvme/SSH_remote/20250804LoadingIdentification
# 应变窗口形状: (1278, 2048, 10)
# 载荷窗口形状: (1278, 2048, 1)
# TCN模型总参数数量: 4,259,521
# 模型结构:
# TCNModel(
#   (tcn): TemporalConvNet(
#     (network): Sequential(
#       (0): TemporalBlock(
#         (conv1): Conv1d(10, 64, kernel_size=(3,), stride=(1,), padding=(2,))
#         (chomp1): Chomp1d()
#         (relu1): ReLU()
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (conv2): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(2,))
#         (chomp2): Chomp1d()
#         (relu2): ReLU()
#         (dropout2): Dropout(p=0.2, inplace=False)
#         (net): Sequential(
#           (0): Conv1d(10, 64, kernel_size=(3,), stride=(1,), padding=(2,))
#           (1): Chomp1d()
#           (2): ReLU()
#           (3): Dropout(p=0.2, inplace=False)
#           (4): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(2,))
#           (5): Chomp1d()
#           (6): ReLU()
#           (7): Dropout(p=0.2, inplace=False)
#         )
#         (downsample): Conv1d(10, 64, kernel_size=(1,), stride=(1,))
#         (relu): ReLU()
#       )
#       (1): TemporalBlock(
#         (conv1): Conv1d(64, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#         (chomp1): Chomp1d()
#         (relu1): ReLU()
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (conv2): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#         (chomp2): Chomp1d()
#         (relu2): ReLU()
#         (dropout2): Dropout(p=0.2, inplace=False)
#         (net): Sequential(
#           (0): Conv1d(64, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#           (1): Chomp1d()
#           (2): ReLU()
#           (3): Dropout(p=0.2, inplace=False)
#           (4): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#           (5): Chomp1d()
#           (6): ReLU()
#           (7): Dropout(p=0.2, inplace=False)
#         )
#         (downsample): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#         (relu): ReLU()
#       )
#       (2): TemporalBlock(
#         (conv1): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#         (chomp1): Chomp1d()
#         (relu1): ReLU()
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (conv2): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#         (chomp2): Chomp1d()
#         (relu2): ReLU()
#         (dropout2): Dropout(p=0.2, inplace=False)
#         (net): Sequential(
#           (0): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#           (1): Chomp1d()
#           (2): ReLU()
#           (3): Dropout(p=0.2, inplace=False)
#           (4): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#           (5): Chomp1d()
#           (6): ReLU()
#           (7): Dropout(p=0.2, inplace=False)
#         )
#         (downsample): Conv1d(128, 256, kernel_size=(1,), stride=(1,))
#         (relu): ReLU()
#       )
#       (3): TemporalBlock(
#         (conv1): Conv1d(256, 512, kernel_size=(3,), stride=(1,), padding=(16,), dilation=(8,))
#         (chomp1): Chomp1d()
#         (relu1): ReLU()
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (conv2): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(16,), dilation=(8,))
#         (chomp2): Chomp1d()
#         (relu2): ReLU()
#         (dropout2): Dropout(p=0.2, inplace=False)
#         (net): Sequential(
#           (0): Conv1d(256, 512, kernel_size=(3,), stride=(1,), padding=(16,), dilation=(8,))
#           (1): Chomp1d()
#           (2): ReLU()
#           (3): Dropout(p=0.2, inplace=False)
#           (4): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(16,), dilation=(8,))
#           (5): Chomp1d()
#           (6): ReLU()
#           (7): Dropout(p=0.2, inplace=False)
#         )
#         (downsample): Conv1d(256, 512, kernel_size=(1,), stride=(1,))
#         (relu): ReLU()
#       )
#       (4): TemporalBlock(
#         (conv1): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(32,), dilation=(16,))
#         (chomp1): Chomp1d()
#         (relu1): ReLU()
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (conv2): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(32,), dilation=(16,))
#         (chomp2): Chomp1d()
#         (relu2): ReLU()
#         (dropout2): Dropout(p=0.2, inplace=False)
#         (net): Sequential(
#           (0): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(32,), dilation=(16,))
#           (1): Chomp1d()
#           (2): ReLU()
#           (3): Dropout(p=0.2, inplace=False)
#           (4): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(32,), dilation=(16,))
#           (5): Chomp1d()
#           (6): ReLU()
#           (7): Dropout(p=0.2, inplace=False)
#         )
#         (relu): ReLU()
#       )
#       (5): TemporalBlock(
#         (conv1): Conv1d(512, 256, kernel_size=(3,), stride=(1,), padding=(64,), dilation=(32,))
#         (chomp1): Chomp1d()
#         (relu1): ReLU()
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (conv2): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(64,), dilation=(32,))
#         (chomp2): Chomp1d()
#         (relu2): ReLU()
#         (dropout2): Dropout(p=0.2, inplace=False)
#         (net): Sequential(
#           (0): Conv1d(512, 256, kernel_size=(3,), stride=(1,), padding=(64,), dilation=(32,))
#           (1): Chomp1d()
#           (2): ReLU()
#           (3): Dropout(p=0.2, inplace=False)
#           (4): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(64,), dilation=(32,))
#           (5): Chomp1d()
#           (6): ReLU()
#           (7): Dropout(p=0.2, inplace=False)
#         )
#         (downsample): Conv1d(512, 256, kernel_size=(1,), stride=(1,))
#         (relu): ReLU()
#       )
#       (6): TemporalBlock(
#         (conv1): Conv1d(256, 128, kernel_size=(3,), stride=(1,), padding=(128,), dilation=(64,))
#         (chomp1): Chomp1d()
#         (relu1): ReLU()
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (conv2): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(128,), dilation=(64,))
#         (chomp2): Chomp1d()
#         (relu2): ReLU()
#         (dropout2): Dropout(p=0.2, inplace=False)
#         (net): Sequential(
#           (0): Conv1d(256, 128, kernel_size=(3,), stride=(1,), padding=(128,), dilation=(64,))
#           (1): Chomp1d()
#           (2): ReLU()
#           (3): Dropout(p=0.2, inplace=False)
#           (4): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(128,), dilation=(64,))
#           (5): Chomp1d()
#           (6): ReLU()
#           (7): Dropout(p=0.2, inplace=False)
#         )
#         (downsample): Conv1d(256, 128, kernel_size=(1,), stride=(1,))
#         (relu): ReLU()
#       )
#       (7): TemporalBlock(
#         (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(256,), dilation=(128,))
#         (chomp1): Chomp1d()
#         (relu1): ReLU()
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (conv2): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(256,), dilation=(128,))
#         (chomp2): Chomp1d()
#         (relu2): ReLU()
#         (dropout2): Dropout(p=0.2, inplace=False)
#         (net): Sequential(
#           (0): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(256,), dilation=(128,))
#           (1): Chomp1d()
#           (2): ReLU()
#           (3): Dropout(p=0.2, inplace=False)
#           (4): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(256,), dilation=(128,))
#           (5): Chomp1d()
#           (6): ReLU()
#           (7): Dropout(p=0.2, inplace=False)
#         )
#         (downsample): Conv1d(128, 64, kernel_size=(1,), stride=(1,))
#         (relu): ReLU()
#       )
#     )
#   )
#   (linear): Linear(in_features=64, out_features=1, bias=True)
# )
# 使用设备: cuda
# 开始训练TCN模型...
# Epoch [1/300], Train Loss: 1.002303, Val Loss: 1.002052
# Epoch [2/300], Train Loss: 1.000485, Val Loss: 1.002032
# Epoch [3/300], Train Loss: 1.000478, Val Loss: 1.002033
# Epoch [4/300], Train Loss: 1.000447, Val Loss: 1.001511
# Epoch [5/300], Train Loss: 0.983295, Val Loss: 0.940913
# Epoch [6/300], Train Loss: 0.898723, Val Loss: 0.825595
# Epoch [7/300], Train Loss: 0.789975, Val Loss: 0.711912
# Epoch [8/300], Train Loss: 0.717692, Val Loss: 0.662237
# Epoch [9/300], Train Loss: 0.674626, Val Loss: 0.619832
# Epoch [10/300], Train Loss: 0.646368, Val Loss: 0.614016
# Epoch [11/300], Train Loss: 0.624161, Val Loss: 0.572130
# Epoch [12/300], Train Loss: 0.602316, Val Loss: 0.548327
# Epoch [13/300], Train Loss: 0.579461, Val Loss: 0.533472
# Epoch [14/300], Train Loss: 0.566475, Val Loss: 0.525134
# Epoch [15/300], Train Loss: 0.549896, Val Loss: 0.513311
# Epoch [16/300], Train Loss: 0.539985, Val Loss: 0.495556
# Epoch [17/300], Train Loss: 0.528117, Val Loss: 0.487761
# Epoch [18/300], Train Loss: 0.525048, Val Loss: 0.482969
# Epoch [19/300], Train Loss: 0.510859, Val Loss: 0.470616
# Epoch [20/300], Train Loss: 0.497388, Val Loss: 0.463638
# Epoch [21/300], Train Loss: 0.491995, Val Loss: 0.478467
# Epoch [22/300], Train Loss: 0.499285, Val Loss: 0.465225
# Epoch [23/300], Train Loss: 0.478685, Val Loss: 0.444352
# Epoch [24/300], Train Loss: 0.474653, Val Loss: 0.442271
# Epoch [25/300], Train Loss: 0.466480, Val Loss: 0.423423
# Epoch [26/300], Train Loss: 0.456443, Val Loss: 0.424135
# Epoch [27/300], Train Loss: 0.453410, Val Loss: 0.413463
# Epoch [28/300], Train Loss: 0.446690, Val Loss: 0.415521
# Epoch [29/300], Train Loss: 0.450187, Val Loss: 0.424394
# Epoch [30/300], Train Loss: 0.438282, Val Loss: 0.409626
# Epoch [31/300], Train Loss: 0.433394, Val Loss: 0.417444
# Epoch [32/300], Train Loss: 0.426390, Val Loss: 0.391243
# Epoch [33/300], Train Loss: 0.429392, Val Loss: 0.401582
# Epoch [34/300], Train Loss: 0.416785, Val Loss: 0.392361
# Epoch [35/300], Train Loss: 0.411941, Val Loss: 0.397950
# Epoch [36/300], Train Loss: 0.409335, Val Loss: 0.376157
# Epoch [37/300], Train Loss: 0.408005, Val Loss: 0.404113
# Epoch [38/300], Train Loss: 0.426055, Val Loss: 0.395015
# Epoch [39/300], Train Loss: 0.396566, Val Loss: 0.373274
# Epoch [40/300], Train Loss: 0.393715, Val Loss: 0.366801
# Epoch [41/300], Train Loss: 0.393383, Val Loss: 0.387856
# Epoch [42/300], Train Loss: 0.390707, Val Loss: 0.378177
# Epoch [43/300], Train Loss: 0.388554, Val Loss: 0.371480
# Epoch [44/300], Train Loss: 0.381427, Val Loss: 0.367961
# Epoch [45/300], Train Loss: 0.378395, Val Loss: 0.356203
# Epoch [46/300], Train Loss: 0.372745, Val Loss: 0.357480
# Epoch [47/300], Train Loss: 0.371223, Val Loss: 0.347370
# Epoch [48/300], Train Loss: 0.369157, Val Loss: 0.351698
# Epoch [49/300], Train Loss: 0.365942, Val Loss: 0.344176
# Epoch [50/300], Train Loss: 0.365300, Val Loss: 0.365880
# Epoch [51/300], Train Loss: 0.367678, Val Loss: 0.344267
# Epoch [52/300], Train Loss: 0.355562, Val Loss: 0.360696
# Epoch [53/300], Train Loss: 0.357024, Val Loss: 0.340473
# Epoch [54/300], Train Loss: 0.356501, Val Loss: 0.344486
# Epoch [55/300], Train Loss: 0.350607, Val Loss: 0.341052
# Epoch [56/300], Train Loss: 0.349725, Val Loss: 0.337979
# Epoch [57/300], Train Loss: 0.346157, Val Loss: 0.336164
# Epoch [58/300], Train Loss: 0.342045, Val Loss: 0.336373
# Epoch [59/300], Train Loss: 0.348323, Val Loss: 0.342718
# Epoch [60/300], Train Loss: 0.343559, Val Loss: 0.325880
# Epoch [61/300], Train Loss: 0.338527, Val Loss: 0.326563
# Epoch [62/300], Train Loss: 0.336932, Val Loss: 0.323059
# Epoch [63/300], Train Loss: 0.333213, Val Loss: 0.334812
# Epoch [64/300], Train Loss: 0.331263, Val Loss: 0.322633
# Epoch [65/300], Train Loss: 0.330001, Val Loss: 0.334010
# Epoch [66/300], Train Loss: 0.335440, Val Loss: 0.318811
# Epoch [67/300], Train Loss: 0.327828, Val Loss: 0.311307
# Epoch [68/300], Train Loss: 0.324272, Val Loss: 0.303131
# Epoch [69/300], Train Loss: 0.326275, Val Loss: 0.316533
# Epoch [70/300], Train Loss: 0.321553, Val Loss: 0.307173
# Epoch [71/300], Train Loss: 0.319061, Val Loss: 0.311396
# Epoch [72/300], Train Loss: 0.328599, Val Loss: 0.328561
# Epoch [73/300], Train Loss: 0.322462, Val Loss: 0.314625
# Epoch [74/300], Train Loss: 0.313544, Val Loss: 0.306722
# Epoch [75/300], Train Loss: 0.312823, Val Loss: 0.307515
# Epoch [76/300], Train Loss: 0.311991, Val Loss: 0.303174
# Epoch [77/300], Train Loss: 0.313104, Val Loss: 0.312996
# Epoch [78/300], Train Loss: 0.311536, Val Loss: 0.313928
# Epoch [79/300], Train Loss: 0.310165, Val Loss: 0.298709
# Epoch [80/300], Train Loss: 0.307008, Val Loss: 0.291754
# Epoch [81/300], Train Loss: 0.305396, Val Loss: 0.299802
# Epoch [82/300], Train Loss: 0.318422, Val Loss: 0.341890
# Epoch [83/300], Train Loss: 0.313572, Val Loss: 0.296969
# Epoch [84/300], Train Loss: 0.303259, Val Loss: 0.300260
# Epoch [85/300], Train Loss: 0.301527, Val Loss: 0.295226
# Epoch [86/300], Train Loss: 0.303375, Val Loss: 0.297725
# Epoch [87/300], Train Loss: 0.303285, Val Loss: 0.311395
# Epoch [88/300], Train Loss: 0.297775, Val Loss: 0.291645
# Epoch [89/300], Train Loss: 0.295809, Val Loss: 0.284648
# Epoch [90/300], Train Loss: 0.293566, Val Loss: 0.283670
# Epoch [91/300], Train Loss: 0.297852, Val Loss: 0.294410
# Epoch [92/300], Train Loss: 0.295532, Val Loss: 0.276138
# Epoch [93/300], Train Loss: 0.294877, Val Loss: 0.287438
# Epoch [94/300], Train Loss: 0.289720, Val Loss: 0.281596
# Epoch [95/300], Train Loss: 0.290577, Val Loss: 0.300975
# Epoch [96/300], Train Loss: 0.293097, Val Loss: 0.287950
# Epoch [97/300], Train Loss: 0.286654, Val Loss: 0.283203
# Epoch [98/300], Train Loss: 0.286959, Val Loss: 0.282921
# Epoch [99/300], Train Loss: 0.290386, Val Loss: 0.285040
# Epoch [100/300], Train Loss: 0.288012, Val Loss: 0.300799
# Epoch [101/300], Train Loss: 0.288550, Val Loss: 0.281544
# Epoch [102/300], Train Loss: 0.285779, Val Loss: 0.295193
# Epoch [103/300], Train Loss: 0.285500, Val Loss: 0.285901
# Epoch [104/300], Train Loss: 0.282075, Val Loss: 0.290962
# Epoch [105/300], Train Loss: 0.283576, Val Loss: 0.284559
# Epoch [106/300], Train Loss: 0.280166, Val Loss: 0.278490
# Epoch [107/300], Train Loss: 0.278006, Val Loss: 0.274583
# Epoch [108/300], Train Loss: 0.281319, Val Loss: 0.279994
# Epoch [109/300], Train Loss: 0.282072, Val Loss: 0.275131
# Epoch [110/300], Train Loss: 0.277544, Val Loss: 0.271754
# Epoch [111/300], Train Loss: 0.276816, Val Loss: 0.270554
# Epoch [112/300], Train Loss: 0.275399, Val Loss: 0.260237
# Epoch [113/300], Train Loss: 0.279658, Val Loss: 0.278543
# Epoch [114/300], Train Loss: 0.274847, Val Loss: 0.269976
# Epoch [115/300], Train Loss: 0.274533, Val Loss: 0.280397
# Epoch [116/300], Train Loss: 0.277179, Val Loss: 0.305552
# Epoch [117/300], Train Loss: 0.278132, Val Loss: 0.288071
# Epoch [118/300], Train Loss: 0.278460, Val Loss: 0.268583
# Epoch [119/300], Train Loss: 0.271710, Val Loss: 0.262874
# Epoch [120/300], Train Loss: 0.268591, Val Loss: 0.271704
# Epoch [121/300], Train Loss: 0.269014, Val Loss: 0.271763
# Epoch [122/300], Train Loss: 0.268818, Val Loss: 0.273437
# Epoch [123/300], Train Loss: 0.266960, Val Loss: 0.265023
# Epoch [124/300], Train Loss: 0.271404, Val Loss: 0.269430
# Epoch [125/300], Train Loss: 0.265012, Val Loss: 0.257960
# Epoch [126/300], Train Loss: 0.268678, Val Loss: 0.271212
# Epoch [127/300], Train Loss: 0.265521, Val Loss: 0.271348
# Epoch [128/300], Train Loss: 0.265141, Val Loss: 0.270129
# Epoch [129/300], Train Loss: 0.267197, Val Loss: 0.261873
# Epoch [130/300], Train Loss: 0.266928, Val Loss: 0.283983
# Epoch [131/300], Train Loss: 0.266113, Val Loss: 0.271866
# Epoch [132/300], Train Loss: 0.265257, Val Loss: 0.272559
# Epoch [133/300], Train Loss: 0.266351, Val Loss: 0.273982
# Epoch [134/300], Train Loss: 0.260890, Val Loss: 0.259933
# Epoch [135/300], Train Loss: 0.259959, Val Loss: 0.262574
# Epoch [136/300], Train Loss: 0.261440, Val Loss: 0.272362
# Epoch [137/300], Train Loss: 0.260277, Val Loss: 0.254878
# Epoch [138/300], Train Loss: 0.262688, Val Loss: 0.263613
# Epoch [139/300], Train Loss: 0.262613, Val Loss: 0.255927
# Epoch [140/300], Train Loss: 0.259130, Val Loss: 0.266686
# Epoch [141/300], Train Loss: 0.262920, Val Loss: 0.271383
# Epoch [142/300], Train Loss: 0.257915, Val Loss: 0.254731
# Epoch [143/300], Train Loss: 0.256283, Val Loss: 0.265630
# Epoch [144/300], Train Loss: 0.256652, Val Loss: 0.255203
# Epoch [145/300], Train Loss: 0.255020, Val Loss: 0.263088
# Epoch [146/300], Train Loss: 0.254722, Val Loss: 0.260606
# Epoch [147/300], Train Loss: 0.257709, Val Loss: 0.258769
# Epoch [148/300], Train Loss: 0.259881, Val Loss: 0.258901
# Epoch [149/300], Train Loss: 0.258559, Val Loss: 0.253688
# Epoch [150/300], Train Loss: 0.251449, Val Loss: 0.252985
# Epoch [151/300], Train Loss: 0.254180, Val Loss: 0.254911
# Epoch [152/300], Train Loss: 0.252698, Val Loss: 0.257075
# Epoch [153/300], Train Loss: 0.251683, Val Loss: 0.253999
# Epoch [154/300], Train Loss: 0.252086, Val Loss: 0.251058
# Epoch [155/300], Train Loss: 0.250359, Val Loss: 0.250463
# Epoch [156/300], Train Loss: 0.249262, Val Loss: 0.250537
# Epoch [157/300], Train Loss: 0.250880, Val Loss: 0.256641
# Epoch [158/300], Train Loss: 0.256066, Val Loss: 0.251646
# Epoch [159/300], Train Loss: 0.251236, Val Loss: 0.248020
# Epoch [160/300], Train Loss: 0.248671, Val Loss: 0.281953
# Epoch [161/300], Train Loss: 0.250041, Val Loss: 0.249485
# Epoch [162/300], Train Loss: 0.249129, Val Loss: 0.257228
# Epoch [163/300], Train Loss: 0.247771, Val Loss: 0.249346
# Epoch [164/300], Train Loss: 0.253049, Val Loss: 0.252837
# Epoch [165/300], Train Loss: 0.250346, Val Loss: 0.245525
# Epoch [166/300], Train Loss: 0.249504, Val Loss: 0.254160
# Epoch [167/300], Train Loss: 0.250954, Val Loss: 0.255087
# Epoch [168/300], Train Loss: 0.246047, Val Loss: 0.258382
# Epoch [169/300], Train Loss: 0.246476, Val Loss: 0.245313
# Epoch [170/300], Train Loss: 0.245576, Val Loss: 0.245014
# Epoch [171/300], Train Loss: 0.243500, Val Loss: 0.240917
# Epoch [172/300], Train Loss: 0.244693, Val Loss: 0.244648
# Epoch [173/300], Train Loss: 0.243662, Val Loss: 0.240336
# Epoch [174/300], Train Loss: 0.244792, Val Loss: 0.246741
# Epoch [175/300], Train Loss: 0.243534, Val Loss: 0.249946
# Epoch [176/300], Train Loss: 0.245128, Val Loss: 0.258019
# Epoch [177/300], Train Loss: 0.242764, Val Loss: 0.248355
# Epoch [178/300], Train Loss: 0.240831, Val Loss: 0.246380
# Epoch [179/300], Train Loss: 0.240546, Val Loss: 0.243285
# Epoch [180/300], Train Loss: 0.242129, Val Loss: 0.254586
# Epoch [181/300], Train Loss: 0.244604, Val Loss: 0.240901
# Epoch [182/300], Train Loss: 0.239759, Val Loss: 0.243216
# Epoch [183/300], Train Loss: 0.242183, Val Loss: 0.241926
# Epoch [184/300], Train Loss: 0.238209, Val Loss: 0.241456
# Epoch [185/300], Train Loss: 0.238191, Val Loss: 0.254266
# Epoch [186/300], Train Loss: 0.237957, Val Loss: 0.246349
# Epoch [187/300], Train Loss: 0.236642, Val Loss: 0.248560
# Epoch [188/300], Train Loss: 0.237625, Val Loss: 0.235109
# Epoch [189/300], Train Loss: 0.236078, Val Loss: 0.244723
# Epoch [190/300], Train Loss: 0.236317, Val Loss: 0.236914
# Epoch [191/300], Train Loss: 0.242136, Val Loss: 0.242594
# Epoch [192/300], Train Loss: 0.234960, Val Loss: 0.237524
# Epoch [193/300], Train Loss: 0.233653, Val Loss: 0.237585
# Epoch [194/300], Train Loss: 0.239618, Val Loss: 0.236739
# Epoch [195/300], Train Loss: 0.235387, Val Loss: 0.243262
# Epoch [196/300], Train Loss: 0.233157, Val Loss: 0.232307
# Epoch [197/300], Train Loss: 0.233571, Val Loss: 0.241125
# Epoch [198/300], Train Loss: 0.237020, Val Loss: 0.238123
# Epoch [199/300], Train Loss: 0.233781, Val Loss: 0.239343
# Epoch [200/300], Train Loss: 0.232203, Val Loss: 0.233431
# Epoch [201/300], Train Loss: 0.233084, Val Loss: 0.238834
# Epoch [202/300], Train Loss: 0.233397, Val Loss: 0.235107
# Epoch [203/300], Train Loss: 0.232642, Val Loss: 0.249782
# Epoch [204/300], Train Loss: 0.232335, Val Loss: 0.234438
# Epoch [205/300], Train Loss: 0.233231, Val Loss: 0.237075
# Epoch [206/300], Train Loss: 0.230984, Val Loss: 0.241483
# Epoch [207/300], Train Loss: 0.233196, Val Loss: 0.234220
# Epoch [208/300], Train Loss: 0.234450, Val Loss: 0.251199
# Epoch [209/300], Train Loss: 0.233572, Val Loss: 0.236579
# Epoch [210/300], Train Loss: 0.238176, Val Loss: 0.246602
# Epoch [211/300], Train Loss: 0.236333, Val Loss: 0.259697
# Epoch [212/300], Train Loss: 0.236275, Val Loss: 0.251891
# Epoch [213/300], Train Loss: 0.234036, Val Loss: 0.230115
# Epoch [214/300], Train Loss: 0.227614, Val Loss: 0.233216
# Epoch [215/300], Train Loss: 0.228230, Val Loss: 0.235988
# Epoch [216/300], Train Loss: 0.227760, Val Loss: 0.234096
# Epoch [217/300], Train Loss: 0.227522, Val Loss: 0.233916
# Epoch [218/300], Train Loss: 0.227322, Val Loss: 0.242248
# Epoch [219/300], Train Loss: 0.227314, Val Loss: 0.231913
# Epoch [220/300], Train Loss: 0.226479, Val Loss: 0.233185
# Epoch [221/300], Train Loss: 0.226628, Val Loss: 0.230937
# Epoch [222/300], Train Loss: 0.224806, Val Loss: 0.231176
# Epoch [223/300], Train Loss: 0.225809, Val Loss: 0.233022
# Epoch [224/300], Train Loss: 0.224657, Val Loss: 0.231745
# Epoch [225/300], Train Loss: 0.231609, Val Loss: 0.229819
# Epoch [226/300], Train Loss: 0.226000, Val Loss: 0.241038
# Epoch [227/300], Train Loss: 0.226987, Val Loss: 0.239718
# Epoch [228/300], Train Loss: 0.227448, Val Loss: 0.238256
# Epoch [229/300], Train Loss: 0.223856, Val Loss: 0.234661
# Epoch [230/300], Train Loss: 0.224490, Val Loss: 0.238327
# Epoch [231/300], Train Loss: 0.223671, Val Loss: 0.223573
# Epoch [232/300], Train Loss: 0.224371, Val Loss: 0.225091
# Epoch [233/300], Train Loss: 0.224553, Val Loss: 0.241495
# Epoch [234/300], Train Loss: 0.224683, Val Loss: 0.229025
# Epoch [235/300], Train Loss: 0.221971, Val Loss: 0.230550
# Epoch [236/300], Train Loss: 0.222460, Val Loss: 0.228343
# Epoch [237/300], Train Loss: 0.222968, Val Loss: 0.230677
# Epoch [238/300], Train Loss: 0.223929, Val Loss: 0.233979
# Epoch [239/300], Train Loss: 0.222138, Val Loss: 0.231921
# Epoch [240/300], Train Loss: 0.229085, Val Loss: 0.233537
# Epoch [241/300], Train Loss: 0.224517, Val Loss: 0.223393
# Epoch [242/300], Train Loss: 0.220496, Val Loss: 0.231544
# Epoch [243/300], Train Loss: 0.219196, Val Loss: 0.229077
# Epoch [244/300], Train Loss: 0.226231, Val Loss: 0.239536
# Epoch [245/300], Train Loss: 0.220746, Val Loss: 0.239547
# Epoch [246/300], Train Loss: 0.223424, Val Loss: 0.232514
# Epoch [247/300], Train Loss: 0.220412, Val Loss: 0.231881
# Epoch [248/300], Train Loss: 0.219983, Val Loss: 0.222382
# Epoch [249/300], Train Loss: 0.219677, Val Loss: 0.226371
# Epoch [250/300], Train Loss: 0.219182, Val Loss: 0.240725
# Epoch [251/300], Train Loss: 0.219901, Val Loss: 0.229684
# Epoch [252/300], Train Loss: 0.221100, Val Loss: 0.215885
# Epoch [253/300], Train Loss: 0.220047, Val Loss: 0.221238
# Epoch [254/300], Train Loss: 0.222121, Val Loss: 0.222970
# Epoch [255/300], Train Loss: 0.217893, Val Loss: 0.231947
# Epoch [256/300], Train Loss: 0.225011, Val Loss: 0.229610
# Epoch [257/300], Train Loss: 0.218798, Val Loss: 0.218769
# Epoch [258/300], Train Loss: 0.217912, Val Loss: 0.230667
# Epoch [259/300], Train Loss: 0.216683, Val Loss: 0.226429
# Epoch [260/300], Train Loss: 0.218058, Val Loss: 0.223173
# Epoch [261/300], Train Loss: 0.221641, Val Loss: 0.230983
# Epoch [262/300], Train Loss: 0.216940, Val Loss: 0.227071
# Epoch [263/300], Train Loss: 0.215598, Val Loss: 0.229578
# Epoch [264/300], Train Loss: 0.216242, Val Loss: 0.231793
# Epoch [265/300], Train Loss: 0.219729, Val Loss: 0.228994
# Epoch [266/300], Train Loss: 0.217856, Val Loss: 0.227108
# Epoch [267/300], Train Loss: 0.215466, Val Loss: 0.227435
# Epoch [268/300], Train Loss: 0.216446, Val Loss: 0.221818
# Epoch [269/300], Train Loss: 0.215971, Val Loss: 0.225483
# Epoch [270/300], Train Loss: 0.216629, Val Loss: 0.230836
# Epoch [271/300], Train Loss: 0.214308, Val Loss: 0.224086
# Epoch [272/300], Train Loss: 0.216761, Val Loss: 0.219229
# Epoch 00273: reducing learning rate of group 0 to 5.0000e-04.
# Epoch [273/300], Train Loss: 0.213370, Val Loss: 0.221095
# Epoch [274/300], Train Loss: 0.208336, Val Loss: 0.217893
# Epoch [275/300], Train Loss: 0.206950, Val Loss: 0.217841
# Epoch [276/300], Train Loss: 0.206387, Val Loss: 0.216377
# Epoch [277/300], Train Loss: 0.205845, Val Loss: 0.214174
# Epoch [278/300], Train Loss: 0.205846, Val Loss: 0.219630
# Epoch [279/300], Train Loss: 0.205896, Val Loss: 0.218950
# Epoch [280/300], Train Loss: 0.205241, Val Loss: 0.215535
# Epoch [281/300], Train Loss: 0.205127, Val Loss: 0.215107
# Epoch [282/300], Train Loss: 0.204363, Val Loss: 0.217456
# Epoch [283/300], Train Loss: 0.204150, Val Loss: 0.214233
# Epoch [284/300], Train Loss: 0.203933, Val Loss: 0.214240
# Epoch [285/300], Train Loss: 0.203486, Val Loss: 0.218816
# Epoch [286/300], Train Loss: 0.204199, Val Loss: 0.213651
# Epoch [287/300], Train Loss: 0.204179, Val Loss: 0.214080
# Epoch [288/300], Train Loss: 0.203519, Val Loss: 0.215011
# Epoch [289/300], Train Loss: 0.203231, Val Loss: 0.218170
# Epoch [290/300], Train Loss: 0.203646, Val Loss: 0.210171
# Epoch [291/300], Train Loss: 0.203282, Val Loss: 0.213241
# Epoch [292/300], Train Loss: 0.202804, Val Loss: 0.217046
# Epoch [293/300], Train Loss: 0.202023, Val Loss: 0.214821
# Epoch [294/300], Train Loss: 0.203186, Val Loss: 0.218829
# Epoch [295/300], Train Loss: 0.202362, Val Loss: 0.211120
# Epoch [296/300], Train Loss: 0.202832, Val Loss: 0.214081
# Epoch [297/300], Train Loss: 0.202731, Val Loss: 0.216455
# Epoch [298/300], Train Loss: 0.203137, Val Loss: 0.216427
# Epoch [299/300], Train Loss: 0.201836, Val Loss: 0.211626
# Epoch [300/300], Train Loss: 0.201496, Val Loss: 0.212182
# 训练完成！
# 正在评估TCN模型...
# 处理批次 1/8
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# 预测数据形状: (256, 2048, 1)
# 目标数据形状: (256, 2048, 1)
#
# === TCN模型评估结果 ===
# 模型参数数量: 4,259,521
# RMSE:  5.246301
# MAE:   3.435884
# RRMSE: 77.2018%
# TRAC:  0.796947
# 相关系数R: 0.892719
#
# === 额外统计信息 ===
# 真实值均值: 0.000671
# 预测值均值: -0.170594
# 真实值标准差: 11.455333
# 预测值标准差: 9.305073
#
# 评估指标已保存到 tcn_evaluation_metrics.json
# 保存最佳TCN模型，验证损失: 0.210171
# 训练损失历史已保存到 tcn_loss_history.json
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# TCN模型感受野: 511 个时间步
# 相对于序列长度 2048 的比例: 24.95%
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# ...
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# 所有任务完成！
# 生成的文件:
# - best_tcn_model.pth: 最佳模型权重
# - best_tcn_model_dwell.pth: 完整模型信息
# - tcn_evaluation_metrics.json: 评估指标
# - tcn_loss_history.json: 训练历史
# - tcn_training_loss.png: 损失曲线图
# - tcn_model_analysis.png: 模型分析图
# - strain_scaler.save: 应变数据标准化器
# - load_scaler.save: 载荷数据标准化器
#
# TCN模型特点:
# - 总参数量: 4,259,521
# - 网络层数: 8
# - 感受野大小: 511
# - 并行训练能力强
# - 计算效率高
